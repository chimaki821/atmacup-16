# %%
# 必要ライブラリのimportとデータの読み込み
import pandas as pd
import numpy as np

yado = pd.read_csv("in/yado.csv", dtype={"yad_no":int}) 
train_log = pd.read_csv("in/train_log.csv", dtype={"session_id":str, "seq_no":int, "yad_no":int})
train_label = pd.read_csv("in/train_label.csv", dtype={"session_id":str, "yad_no":int})
test_log = pd.read_csv("in/test_log.csv", dtype={"session_id":str, "seq_no":int, "yad_no":int})
test_session = pd.read_csv("in/test_session.csv", dtype={"session_id":str})

# %% [markdown]
# ### パラメータ

# %%
#### typeが違う時のスコアをどの程度落とすか
DECREASE_RATE = 0.95
DECREASE_RATE2 = 0.65

#### 最後から二番目から見た時のD[v][r]に重み付け
SECOND_WEIGHT = 0.5
SECOND_WEIGHT2 = 0.8

# rate pow
POW1 = 0.56
POW2 = 0.56

# D2
D2_WEIGHT = 1.0

PROD_WEIGHT = 1.2

BASE_POINT = 2

# %% [markdown]
# ### test_labelとtrain_labelでの検索数に大きな差があるやつを見つけたい

# %% [markdown]
# - train と test で時間がずれているので、その部分の考慮が必要
#   - 例えば、yad_no=3338はtestの時にはほとんど人気がない
#   - trainでは上位がディズニー >> USJ なのに対して test ではディズニー < USJ になっている
# - log と label での考察
#   - log で人気でも label では不人気なものがあるかもしれない
#   - 例えばディズニーホテルなど。埋まってて予約できないというケース
#
# これらのケースに当てはまるものは思い切って解答から外してしまう、というアイデアが考えられる。

# %%
train_size, test_size = len(train_log), len(test_log)
print(train_size, test_size)
# Out:
# 419270 250305

# %%
train_yado = train_log["yad_no"].value_counts().reset_index()
train_yado = train_yado.merge(yado, how="left", on='yad_no')

train_label_yado = train_label["yad_no"].value_counts().reset_index()
train_label_yado = train_label_yado.merge(yado, how="left", on="yad_no")

test_yado = test_log["yad_no"].value_counts().reset_index()
test_yado = test_yado.merge(yado, how="left", on="yad_no")

# %%
# yad_no -> 各属性でのcount
# 0除算を防ぐために全てのcountを+1しておく -> そうじゃなくて+10くらいしたほうがいいのでは？
each_counts = [{
    'yad_no': idx,
    'train_log': BASE_POINT,
    'train_label': BASE_POINT,
    'test_log': BASE_POINT
} for idx in range(len(yado) + 1)]

for _, row in train_yado.iterrows():
    yad_no, count = row[0:2]
    each_counts[yad_no]["train_log"] = count + BASE_POINT

for _, row in train_label_yado.iterrows():
    yad_no, count = row[0:2]
    each_counts[yad_no]["train_label"] = count + BASE_POINT

for _, row in test_yado.iterrows():
    yad_no, count = row[0:2]
    each_counts[yad_no]["test_log"] = count + BASE_POINT

# %%
for idx, data in enumerate(each_counts):
    # rate1: ログで出た時の選ばれやすさ
    rate1 = data['train_label'] / max(1, data['train_log'])
    # rate2: train から test での変化率
    rate2 = data['test_log'] / max(1, data['train_log']) * (train_size / test_size)

    # rate1 = pow(rate1, 1.2)
    # rate2 = pow(rate2, 1.2)

    each_counts[idx]['rate1'] = rate1 # type: ignore
    each_counts[idx]['rate2'] = rate2 # type: ignore

# %%
each_counts
# Out:
# [{'yad_no': 0,
#   'train_log': 2,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 1,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 32,
#   'rate1': 1.5,
#   'rate2': 26.800583288388168},
#  {'yad_no': 2,
#   'train_log': 26,
#   'train_label': 16,
#   'test_log': 7,
#   'rate1': 0.6153846153846154,
#   'rate2': 0.4509713534103778},
#  {'yad_no': 3,
#   'train_log': 182,
#   'train_label': 96,
#   'test_log': 32,
#   'rate1': 0.5274725274725275,
#   'rate2': 0.2945119042680019},
#  {'yad_no': 4,
#   'train_log': 52,
#   'train_label': 36,
#   'test_log': 19,
#   'rate1': 0.6923076923076923,
#   'rate2': 0.6120325510569413},
#  {'yad_no': 5,
#   'train_log': 32,
#   'train_label': 22,
#   'test_log': 2,
#   'rate1': 0.6875,
#   'rate2': 0.10468977847026628},
#  {'yad_no': 6,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.75,
#   'rate2': 2.0937955694053256},
#  {'yad_no': 7,
#   'train_log': 24,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.16666666666666666,
#   'rate2': 0.13958637129368837},
#  {'yad_no': 8,
#   'train_log': 2,
#   'train_label': 7,
#   'test_log': 3,
#   'rate1': 3.5,
#   'rate2': 2.5125546832863908},
#  {'yad_no': 9,
#   'train_log': 30,
#   'train_label': 27,
#   'test_log': 10,
#   'rate1': 0.9,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 10,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954},
#  {'yad_no': 11,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 1.116690970349507},
#  {'yad_no': 12,
#   'train_log': 10,
#   'train_label': 3,
#   'test_log': 4,
#   'rate1': 0.3,
#   'rate2': 0.6700145822097042},
#  {'yad_no': 13,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954},
#  {'yad_no': 14,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 15,
#   'train_log': 6,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.8333333333333334,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 16,
#   'train_log': 14,
#   'train_label': 7,
#   'test_log': 7,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 17,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.75,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 18,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 4,
#   'rate1': 0.5,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 19,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954},
#  {'yad_no': 20,
#   'train_log': 7,
#   'train_label': 4,
#   'test_log': 5,
#   'rate1': 0.5714285714285714,
#   'rate2': 1.1964546110887575},
#  {'yad_no': 21,
#   'train_log': 11,
#   'train_label': 7,
#   'test_log': 25,
#   'rate1': 0.6363636363636364,
#   'rate2': 3.8069010352824106},
#  {'yad_no': 22,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 23,
#   'train_log': 83,
#   'train_label': 52,
#   'test_log': 45,
#   'rate1': 0.6265060240963856,
#   'rate2': 0.9081522951637556},
#  {'yad_no': 24,
#   'train_log': 38,
#   'train_label': 16,
#   'test_log': 38,
#   'rate1': 0.42105263157894735,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 25,
#   'train_log': 57,
#   'train_label': 45,
#   'test_log': 53,
#   'rate1': 0.7894736842105263,
#   'rate2': 1.5574900375927334},
#  {'yad_no': 26,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.3333333333333333,
#   'rate2': 1.116690970349507},
#  {'yad_no': 27,
#   'train_log': 16,
#   'train_label': 17,
#   'test_log': 2,
#   'rate1': 1.0625,
#   'rate2': 0.20937955694053256},
#  {'yad_no': 28,
#   'train_log': 130,
#   'train_label': 100,
#   'test_log': 93,
#   'rate1': 0.7692307692307693,
#   'rate2': 1.1982953104904326},
#  {'yad_no': 29,
#   'train_log': 7,
#   'train_label': 6,
#   'test_log': 5,
#   'rate1': 0.8571428571428571,
#   'rate2': 1.1964546110887575},
#  {'yad_no': 30,
#   'train_log': 15,
#   'train_label': 9,
#   'test_log': 7,
#   'rate1': 0.6,
#   'rate2': 0.7816836792446549},
#  {'yad_no': 31,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.75,
#   'rate2': 2.0937955694053256},
#  {'yad_no': 32,
#   'train_log': 58,
#   'train_label': 57,
#   'test_log': 16,
#   'rate1': 0.9827586206896551,
#   'rate2': 0.4620790222135891},
#  {'yad_no': 33,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 4,
#   'rate1': 0.8,
#   'rate2': 1.3400291644194084},
#  {'yad_no': 34,
#   'train_log': 29,
#   'train_label': 13,
#   'test_log': 10,
#   'rate1': 0.4482758620689655,
#   'rate2': 0.5775987777669864},
#  {'yad_no': 35,
#   'train_log': 25,
#   'train_label': 16,
#   'test_log': 7,
#   'rate1': 0.64,
#   'rate2': 0.469010207546793},
#  {'yad_no': 36,
#   'train_log': 11,
#   'train_label': 12,
#   'test_log': 5,
#   'rate1': 1.0909090909090908,
#   'rate2': 0.761380207056482},
#  {'yad_no': 37,
#   'train_log': 13,
#   'train_label': 17,
#   'test_log': 80,
#   'rate1': 1.3076923076923077,
#   'rate2': 10.307916649380065},
#  {'yad_no': 38,
#   'train_log': 25,
#   'train_label': 21,
#   'test_log': 19,
#   'rate1': 0.84,
#   'rate2': 1.273027706198438},
#  {'yad_no': 39,
#   'train_log': 61,
#   'train_label': 38,
#   'test_log': 34,
#   'rate1': 0.6229508196721312,
#   'rate2': 0.9336268768495878},
#  {'yad_no': 40,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.75,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 41,
#   'train_log': 6,
#   'train_label': 5,
#   'test_log': 4,
#   'rate1': 0.8333333333333334,
#   'rate2': 1.116690970349507},
#  {'yad_no': 42,
#   'train_log': 8,
#   'train_label': 3,
#   'test_log': 10,
#   'rate1': 0.375,
#   'rate2': 2.0937955694053256},
#  {'yad_no': 43,
#   'train_log': 124,
#   'train_label': 55,
#   'test_log': 32,
#   'rate1': 0.4435483870967742,
#   'rate2': 0.43226747239335755},
#  {'yad_no': 44,
#   'train_log': 22,
#   'train_label': 13,
#   'test_log': 6,
#   'rate1': 0.5909090909090909,
#   'rate2': 0.4568281242338892},
#  {'yad_no': 45,
#   'train_log': 31,
#   'train_label': 21,
#   'test_log': 38,
#   'rate1': 0.6774193548387096,
#   'rate2': 2.0532704938684483},
#  {'yad_no': 46,
#   'train_log': 36,
#   'train_label': 17,
#   'test_log': 32,
#   'rate1': 0.4722222222222222,
#   'rate2': 1.4889212937993426},
#  {'yad_no': 47,
#   'train_log': 82,
#   'train_label': 82,
#   'test_log': 57,
#   'rate1': 1.0,
#   'rate2': 1.1643546093278396},
#  {'yad_no': 48,
#   'train_log': 4,
#   'train_label': 6,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 49,
#   'train_log': 42,
#   'train_label': 24,
#   'test_log': 31,
#   'rate1': 0.5714285714285714,
#   'rate2': 1.236336431458383},
#  {'yad_no': 50,
#   'train_log': 69,
#   'train_label': 41,
#   'test_log': 32,
#   'rate1': 0.5942028985507246,
#   'rate2': 0.7768285011127005},
#  {'yad_no': 51,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 3,
#   'rate1': 1.0,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 52,
#   'train_log': 45,
#   'train_label': 40,
#   'test_log': 16,
#   'rate1': 0.8888888888888888,
#   'rate2': 0.595568517519737},
#  {'yad_no': 53,
#   'train_log': 5,
#   'train_label': 2,
#   'test_log': 6,
#   'rate1': 0.4,
#   'rate2': 2.0100437466291123},
#  {'yad_no': 54,
#   'train_log': 24,
#   'train_label': 13,
#   'test_log': 47,
#   'rate1': 0.5416666666666666,
#   'rate2': 3.2802797254016767},
#  {'yad_no': 55,
#   'train_log': 35,
#   'train_label': 24,
#   'test_log': 20,
#   'rate1': 0.6857142857142857,
#   'rate2': 0.957163688871006},
#  {'yad_no': 56,
#   'train_log': 29,
#   'train_label': 28,
#   'test_log': 25,
#   'rate1': 0.9655172413793104,
#   'rate2': 1.4439969444174658},
#  {'yad_no': 57,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 58,
#   'train_log': 7,
#   'train_label': 10,
#   'test_log': 14,
#   'rate1': 1.4285714285714286,
#   'rate2': 3.350072911048521},
#  {'yad_no': 59,
#   'train_log': 6,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 60,
#   'train_log': 12,
#   'train_label': 15,
#   'test_log': 12,
#   'rate1': 1.25,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 61,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 5,
#   'rate1': 0.8,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 62,
#   'train_log': 98,
#   'train_label': 92,
#   'test_log': 94,
#   'rate1': 0.9387755102040817,
#   'rate2': 1.6066676206049029},
#  {'yad_no': 63,
#   'train_log': 46,
#   'train_label': 44,
#   'test_log': 22,
#   'rate1': 0.9565217391304348,
#   'rate2': 0.8011043917724724},
#  {'yad_no': 64,
#   'train_log': 5,
#   'train_label': 2,
#   'test_log': 17,
#   'rate1': 0.4,
#   'rate2': 5.695123948782485},
#  {'yad_no': 65,
#   'train_log': 24,
#   'train_label': 29,
#   'test_log': 22,
#   'rate1': 1.2083333333333333,
#   'rate2': 1.535450084230572},
#  {'yad_no': 66,
#   'train_log': 4,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 67,
#   'train_log': 6,
#   'train_label': 5,
#   'test_log': 7,
#   'rate1': 0.8333333333333334,
#   'rate2': 1.9542091981116374},
#  {'yad_no': 68,
#   'train_log': 10,
#   'train_label': 6,
#   'test_log': 6,
#   'rate1': 0.6,
#   'rate2': 1.0050218733145562},
#  {'yad_no': 69,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 3,
#   'rate1': 0.75,
#   'rate2': 1.2562773416431954},
#  {'yad_no': 70,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 3,
#   'rate1': 0.8,
#   'rate2': 1.0050218733145562},
#  {'yad_no': 71,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 4,
#   'rate1': 0.5,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 72,
#   'train_log': 13,
#   'train_label': 12,
#   'test_log': 8,
#   'rate1': 0.9230769230769231,
#   'rate2': 1.0307916649380064},
#  {'yad_no': 73,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.3333333333333333,
#   'rate2': 1.116690970349507},
#  {'yad_no': 74,
#   'train_log': 20,
#   'train_label': 14,
#   'test_log': 19,
#   'rate1': 0.7,
#   'rate2': 1.5912846327480474},
#  {'yad_no': 75,
#   'train_log': 102,
#   'train_label': 56,
#   'test_log': 42,
#   'rate1': 0.5490196078431373,
#   'rate2': 0.689720893451166},
#  {'yad_no': 76,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 6,
#   'rate1': 1.0,
#   'rate2': 2.0100437466291123},
#  {'yad_no': 77,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 1.0,
#   'rate2': 2.7917274258737677},
#  {'yad_no': 78,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 79,
#   'train_log': 28,
#   'train_label': 11,
#   'test_log': 18,
#   'rate1': 0.39285714285714285,
#   'rate2': 1.0768091499798818},
#  {'yad_no': 80,
#   'train_log': 42,
#   'train_label': 32,
#   'test_log': 13,
#   'rate1': 0.7619047619047619,
#   'rate2': 0.5184636648051283},
#  {'yad_no': 81,
#   'train_log': 88,
#   'train_label': 73,
#   'test_log': 22,
#   'rate1': 0.8295454545454546,
#   'rate2': 0.4187591138810651},
#  {'yad_no': 82,
#   'train_log': 157,
#   'train_label': 115,
#   'test_log': 33,
#   'rate1': 0.732484076433121,
#   'rate2': 0.352077726320386},
#  {'yad_no': 83,
#   'train_log': 24,
#   'train_label': 23,
#   'test_log': 39,
#   'rate1': 0.9583333333333334,
#   'rate2': 2.7219342402269233},
#  {'yad_no': 84,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 85,
#   'train_log': 40,
#   'train_label': 39,
#   'test_log': 26,
#   'rate1': 0.975,
#   'rate2': 1.0887736960907695},
#  {'yad_no': 86,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 3,
#   'rate1': 1.3333333333333333,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 87,
#   'train_log': 4,
#   'train_label': 7,
#   'test_log': 41,
#   'rate1': 1.75,
#   'rate2': 17.16912366912367},
#  {'yad_no': 88,
#   'train_log': 13,
#   'train_label': 4,
#   'test_log': 9,
#   'rate1': 0.3076923076923077,
#   'rate2': 1.1596406230552572},
#  {'yad_no': 89,
#   'train_log': 11,
#   'train_label': 10,
#   'test_log': 7,
#   'rate1': 0.9090909090909091,
#   'rate2': 1.0659322898790748},
#  {'yad_no': 90,
#   'train_log': 18,
#   'train_label': 16,
#   'test_log': 20,
#   'rate1': 0.8888888888888888,
#   'rate2': 1.8611516172491784},
#  {'yad_no': 91,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 92,
#   'train_log': 8,
#   'train_label': 10,
#   'test_log': 7,
#   'rate1': 1.25,
#   'rate2': 1.465656898583728},
#  {'yad_no': 93,
#   'train_log': 6,
#   'train_label': 2,
#   'test_log': 6,
#   'rate1': 0.3333333333333333,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 94,
#   'train_log': 6,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 95,
#   'train_log': 32,
#   'train_label': 27,
#   'test_log': 23,
#   'rate1': 0.84375,
#   'rate2': 1.2039324524080621},
#  {'yad_no': 96,
#   'train_log': 40,
#   'train_label': 39,
#   'test_log': 114,
#   'rate1': 0.975,
#   'rate2': 4.773853898244143},
#  {'yad_no': 97,
#   'train_log': 8,
#   'train_label': 7,
#   'test_log': 8,
#   'rate1': 0.875,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 98,
#   'train_log': 8,
#   'train_label': 4,
#   'test_log': 11,
#   'rate1': 0.5,
#   'rate2': 2.303175126345858},
#  {'yad_no': 99,
#   'train_log': 16,
#   'train_label': 21,
#   'test_log': 2,
#   'rate1': 1.3125,
#   'rate2': 0.20937955694053256},
#  {'yad_no': 100,
#   'train_log': 18,
#   'train_label': 18,
#   'test_log': 16,
#   'rate1': 1.0,
#   'rate2': 1.4889212937993426},
#  {'yad_no': 101,
#   'train_log': 206,
#   'train_label': 141,
#   'test_log': 48,
#   'rate1': 0.6844660194174758,
#   'rate2': 0.39029975662701216},
#  {'yad_no': 102,
#   'train_log': 18,
#   'train_label': 17,
#   'test_log': 25,
#   'rate1': 0.9444444444444444,
#   'rate2': 2.326439521561473},
#  {'yad_no': 103,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 6,
#   'rate1': 0.6666666666666666,
#   'rate2': 3.350072911048521},
#  {'yad_no': 104,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 105,
#   'train_log': 95,
#   'train_label': 80,
#   'test_log': 4,
#   'rate1': 0.8421052631578947,
#   'rate2': 0.07052785075891622},
#  {'yad_no': 106,
#   'train_log': 25,
#   'train_label': 22,
#   'test_log': 21,
#   'rate1': 0.88,
#   'rate2': 1.4070306226403788},
#  {'yad_no': 107,
#   'train_log': 26,
#   'train_label': 21,
#   'test_log': 27,
#   'rate1': 0.8076923076923077,
#   'rate2': 1.739460934582886},
#  {'yad_no': 108,
#   'train_log': 10,
#   'train_label': 6,
#   'test_log': 47,
#   'rate1': 0.6,
#   'rate2': 7.8726713409640245},
#  {'yad_no': 109,
#   'train_log': 270,
#   'train_label': 215,
#   'test_log': 92,
#   'rate1': 0.7962962962962963,
#   'rate2': 0.5707531626230813},
#  {'yad_no': 110,
#   'train_log': 3,
#   'train_label': 5,
#   'test_log': 4,
#   'rate1': 1.6666666666666667,
#   'rate2': 2.233381940699014},
#  {'yad_no': 111,
#   'train_log': 42,
#   'train_label': 43,
#   'test_log': 20,
#   'rate1': 1.0238095238095237,
#   'rate2': 0.797636407392505},
#  {'yad_no': 112,
#   'train_log': 18,
#   'train_label': 22,
#   'test_log': 22,
#   'rate1': 1.2222222222222223,
#   'rate2': 2.0472667789740964},
#  {'yad_no': 113,
#   'train_log': 4,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 1.25,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 114,
#   'train_log': 2,
#   'train_label': 6,
#   'test_log': 4,
#   'rate1': 3.0,
#   'rate2': 3.350072911048521},
#  {'yad_no': 115,
#   'train_log': 71,
#   'train_label': 42,
#   'test_log': 34,
#   'rate1': 0.5915492957746479,
#   'rate2': 0.802130133631336},
#  {'yad_no': 116,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.6700145822097042},
#  {'yad_no': 117,
#   'train_log': 36,
#   'train_label': 25,
#   'test_log': 23,
#   'rate1': 0.6944444444444444,
#   'rate2': 1.0701621799182774},
#  {'yad_no': 118,
#   'train_log': 17,
#   'train_label': 10,
#   'test_log': 15,
#   'rate1': 0.5882352941176471,
#   'rate2': 1.4779733431096416},
#  {'yad_no': 119,
#   'train_log': 93,
#   'train_label': 70,
#   'test_log': 46,
#   'rate1': 0.7526881720430108,
#   'rate2': 0.8285126554206019},
#  {'yad_no': 120,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 4,
#   'rate1': 1.0,
#   'rate2': 1.3400291644194084},
#  {'yad_no': 121,
#   'train_log': 72,
#   'train_label': 67,
#   'test_log': 3,
#   'rate1': 0.9305555555555556,
#   'rate2': 0.06979318564684418},
#  {'yad_no': 122,
#   'train_log': 27,
#   'train_label': 22,
#   'test_log': 3,
#   'rate1': 0.8148148148148148,
#   'rate2': 0.18611516172491782},
#  {'yad_no': 123,
#   'train_log': 12,
#   'train_label': 3,
#   'test_log': 6,
#   'rate1': 0.25,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 124,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.3333333333333333,
#   'rate2': 1.116690970349507},
#  {'yad_no': 125,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 126,
#   'train_log': 16,
#   'train_label': 13,
#   'test_log': 9,
#   'rate1': 0.8125,
#   'rate2': 0.9422080062323965},
#  {'yad_no': 127,
#   'train_log': 8,
#   'train_label': 4,
#   'test_log': 5,
#   'rate1': 0.5,
#   'rate2': 1.0468977847026628},
#  {'yad_no': 128,
#   'train_log': 24,
#   'train_label': 30,
#   'test_log': 10,
#   'rate1': 1.25,
#   'rate2': 0.6979318564684419},
#  {'yad_no': 129,
#   'train_log': 8,
#   'train_label': 5,
#   'test_log': 4,
#   'rate1': 0.625,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 130,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 131,
#   'train_log': 15,
#   'train_label': 21,
#   'test_log': 11,
#   'rate1': 1.4,
#   'rate2': 1.2283600673844577},
#  {'yad_no': 132,
#   'train_log': 20,
#   'train_label': 18,
#   'test_log': 15,
#   'rate1': 0.9,
#   'rate2': 1.2562773416431954},
#  {'yad_no': 133,
#   'train_log': 6,
#   'train_label': 5,
#   'test_log': 3,
#   'rate1': 0.8333333333333334,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 134,
#   'train_log': 115,
#   'train_label': 79,
#   'test_log': 91,
#   'rate1': 0.6869565217391305,
#   'rate2': 1.3254636300235452},
#  {'yad_no': 135,
#   'train_log': 43,
#   'train_label': 38,
#   'test_log': 25,
#   'rate1': 0.8837209302325582,
#   'rate2': 0.9738584043745702},
#  {'yad_no': 136,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 20,
#   'rate1': 1.0,
#   'rate2': 6.700145822097042},
#  {'yad_no': 137,
#   'train_log': 39,
#   'train_label': 35,
#   'test_log': 32,
#   'rate1': 0.8974358974358975,
#   'rate2': 1.3743888865840086},
#  {'yad_no': 138,
#   'train_log': 21,
#   'train_label': 25,
#   'test_log': 29,
#   'rate1': 1.1904761904761905,
#   'rate2': 2.3131455814382647},
#  {'yad_no': 139,
#   'train_log': 41,
#   'train_label': 30,
#   'test_log': 25,
#   'rate1': 0.7317073170731707,
#   'rate2': 1.0213636923928417},
#  {'yad_no': 140,
#   'train_log': 16,
#   'train_label': 17,
#   'test_log': 8,
#   'rate1': 1.0625,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 141,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 142,
#   'train_log': 6,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 143,
#   'train_log': 144,
#   'train_label': 68,
#   'test_log': 68,
#   'rate1': 0.4722222222222222,
#   'rate2': 0.7909894373309008},
#  {'yad_no': 144,
#   'train_log': 28,
#   'train_label': 17,
#   'test_log': 31,
#   'rate1': 0.6071428571428571,
#   'rate2': 1.8545046471875741},
#  {'yad_no': 145,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 7,
#   'rate1': 1.5,
#   'rate2': 5.862627594334912},
#  {'yad_no': 146,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 7,
#   'rate1': 0.6666666666666666,
#   'rate2': 3.908418396223275},
#  {'yad_no': 147,
#   'train_log': 4,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 148,
#   'train_log': 108,
#   'train_label': 64,
#   'test_log': 66,
#   'rate1': 0.5925925925925926,
#   'rate2': 1.0236333894870482},
#  {'yad_no': 149,
#   'train_log': 21,
#   'train_label': 21,
#   'test_log': 7,
#   'rate1': 1.0,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 150,
#   'train_log': 59,
#   'train_label': 59,
#   'test_log': 27,
#   'rate1': 1.0,
#   'rate2': 0.7665421067653395},
#  {'yad_no': 151,
#   'train_log': 24,
#   'train_label': 18,
#   'test_log': 8,
#   'rate1': 0.75,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 152,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 153,
#   'train_log': 43,
#   'train_label': 19,
#   'test_log': 6,
#   'rate1': 0.4418604651162791,
#   'rate2': 0.23372601704989682},
#  {'yad_no': 154,
#   'train_log': 22,
#   'train_label': 18,
#   'test_log': 10,
#   'rate1': 0.8181818181818182,
#   'rate2': 0.761380207056482},
#  {'yad_no': 155,
#   'train_log': 18,
#   'train_label': 12,
#   'test_log': 11,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.0236333894870482},
#  {'yad_no': 156,
#   'train_log': 3,
#   'train_label': 6,
#   'test_log': 6,
#   'rate1': 2.0,
#   'rate2': 3.350072911048521},
#  {'yad_no': 157,
#   'train_log': 9,
#   'train_label': 11,
#   'test_log': 2,
#   'rate1': 1.2222222222222223,
#   'rate2': 0.37223032344983564},
#  {'yad_no': 158,
#   'train_log': 20,
#   'train_label': 14,
#   'test_log': 9,
#   'rate1': 0.7,
#   'rate2': 0.7537664049859173},
#  {'yad_no': 159,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 160,
#   'train_log': 28,
#   'train_label': 20,
#   'test_log': 8,
#   'rate1': 0.7142857142857143,
#   'rate2': 0.478581844435503},
#  {'yad_no': 161,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 162,
#   'train_log': 22,
#   'train_label': 11,
#   'test_log': 4,
#   'rate1': 0.5,
#   'rate2': 0.30455208282259283},
#  {'yad_no': 163,
#   'train_log': 11,
#   'train_label': 7,
#   'test_log': 13,
#   'rate1': 0.6363636363636364,
#   'rate2': 1.9795885383468534},
#  {'yad_no': 164,
#   'train_log': 11,
#   'train_label': 5,
#   'test_log': 10,
#   'rate1': 0.45454545454545453,
#   'rate2': 1.522760414112964},
#  {'yad_no': 165,
#   'train_log': 6,
#   'train_label': 6,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 166,
#   'train_log': 7,
#   'train_label': 8,
#   'test_log': 17,
#   'rate1': 1.1428571428571428,
#   'rate2': 4.0679456777017755},
#  {'yad_no': 167,
#   'train_log': 5,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.6,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 168,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 169,
#   'train_log': 33,
#   'train_label': 22,
#   'test_log': 14,
#   'rate1': 0.6666666666666666,
#   'rate2': 0.7106215265860499},
#  {'yad_no': 170,
#   'train_log': 131,
#   'train_label': 61,
#   'test_log': 42,
#   'rate1': 0.46564885496183206,
#   'rate2': 0.5370345887940376},
#  {'yad_no': 171,
#   'train_log': 76,
#   'train_label': 62,
#   'test_log': 7,
#   'rate1': 0.8157894736842105,
#   'rate2': 0.15427967353512925},
#  {'yad_no': 172,
#   'train_log': 17,
#   'train_label': 12,
#   'test_log': 17,
#   'rate1': 0.7058823529411765,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 173,
#   'train_log': 11,
#   'train_label': 10,
#   'test_log': 2,
#   'rate1': 0.9090909090909091,
#   'rate2': 0.30455208282259283},
#  {'yad_no': 174,
#   'train_log': 26,
#   'train_label': 18,
#   'test_log': 14,
#   'rate1': 0.6923076923076923,
#   'rate2': 0.9019427068207556},
#  {'yad_no': 175,
#   'train_log': 30,
#   'train_label': 25,
#   'test_log': 20,
#   'rate1': 0.8333333333333334,
#   'rate2': 1.116690970349507},
#  {'yad_no': 176,
#   'train_log': 45,
#   'train_label': 51,
#   'test_log': 6,
#   'rate1': 1.1333333333333333,
#   'rate2': 0.2233381940699014},
#  {'yad_no': 177,
#   'train_log': 53,
#   'train_label': 19,
#   'test_log': 22,
#   'rate1': 0.3584905660377358,
#   'rate2': 0.6952981513496931},
#  {'yad_no': 178,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 179,
#   'train_log': 47,
#   'train_label': 32,
#   'test_log': 43,
#   'rate1': 0.6808510638297872,
#   'rate2': 1.5324801614370893},
#  {'yad_no': 180,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.8,
#   'rate2': 0.6700145822097042},
#  {'yad_no': 181,
#   'train_log': 6,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.8333333333333334,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 182,
#   'train_log': 13,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.38461538461538464,
#   'rate2': 0.2576979162345016},
#  {'yad_no': 183,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.8,
#   'rate2': 0.6700145822097042},
#  {'yad_no': 184,
#   'train_log': 6,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 185,
#   'train_log': 45,
#   'train_label': 49,
#   'test_log': 2,
#   'rate1': 1.0888888888888888,
#   'rate2': 0.07444606468996713},
#  {'yad_no': 186,
#   'train_log': 37,
#   'train_label': 27,
#   'test_log': 5,
#   'rate1': 0.7297297297297297,
#   'rate2': 0.22635627777354872},
#  {'yad_no': 187,
#   'train_log': 107,
#   'train_label': 61,
#   'test_log': 54,
#   'rate1': 0.5700934579439252,
#   'rate2': 0.8453455009187856},
#  {'yad_no': 188,
#   'train_log': 5,
#   'train_label': 3,
#   'test_log': 3,
#   'rate1': 0.6,
#   'rate2': 1.0050218733145562},
#  {'yad_no': 189,
#   'train_log': 19,
#   'train_label': 15,
#   'test_log': 10,
#   'rate1': 0.7894736842105263,
#   'rate2': 0.8815981344864529},
#  {'yad_no': 190,
#   'train_log': 23,
#   'train_label': 18,
#   'test_log': 6,
#   'rate1': 0.782608695652174,
#   'rate2': 0.43696603187589406},
#  {'yad_no': 191,
#   'train_log': 48,
#   'train_label': 48,
#   'test_log': 38,
#   'rate1': 1.0,
#   'rate2': 1.3260705272900395},
#  {'yad_no': 192,
#   'train_log': 10,
#   'train_label': 8,
#   'test_log': 2,
#   'rate1': 0.8,
#   'rate2': 0.3350072911048521},
#  {'yad_no': 193,
#   'train_log': 79,
#   'train_label': 69,
#   'test_log': 82,
#   'rate1': 0.8734177215189873,
#   'rate2': 1.7386454348479665},
#  {'yad_no': 194,
#   'train_log': 9,
#   'train_label': 9,
#   'test_log': 6,
#   'rate1': 1.0,
#   'rate2': 1.116690970349507},
#  {'yad_no': 195,
#   'train_log': 6,
#   'train_label': 6,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 196,
#   'train_log': 43,
#   'train_label': 24,
#   'test_log': 23,
#   'rate1': 0.5581395348837209,
#   'rate2': 0.8959497320246044},
#  {'yad_no': 197,
#   'train_log': 7,
#   'train_label': 3,
#   'test_log': 8,
#   'rate1': 0.42857142857142855,
#   'rate2': 1.914327377742012},
#  {'yad_no': 198,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 6,
#   'rate1': 0.6666666666666666,
#   'rate2': 3.350072911048521},
#  {'yad_no': 199,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 200,
#   'train_log': 4,
#   'train_label': 4,
#   'test_log': 4,
#   'rate1': 1.0,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 201,
#   'train_log': 7,
#   'train_label': 2,
#   'test_log': 31,
#   'rate1': 0.2857142857142857,
#   'rate2': 7.4180185887502965},
#  {'yad_no': 202,
#   'train_log': 51,
#   'train_label': 40,
#   'test_log': 30,
#   'rate1': 0.7843137254901961,
#   'rate2': 0.9853155620730945},
#  {'yad_no': 203,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 204,
#   'train_log': 13,
#   'train_label': 8,
#   'test_log': 9,
#   'rate1': 0.6153846153846154,
#   'rate2': 1.1596406230552572},
#  {'yad_no': 205,
#   'train_log': 30,
#   'train_label': 29,
#   'test_log': 12,
#   'rate1': 0.9666666666666667,
#   'rate2': 0.6700145822097042},
#  {'yad_no': 206,
#   'train_log': 29,
#   'train_label': 16,
#   'test_log': 20,
#   'rate1': 0.5517241379310345,
#   'rate2': 1.1551975555339729},
#  {'yad_no': 207,
#   'train_log': 2,
#   'train_label': 5,
#   'test_log': 5,
#   'rate1': 2.5,
#   'rate2': 4.187591138810651},
#  {'yad_no': 208,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.8,
#   'rate2': 0.6700145822097042},
#  {'yad_no': 209,
#   'train_log': 19,
#   'train_label': 2,
#   'test_log': 7,
#   'rate1': 0.10526315789473684,
#   'rate2': 0.617118694140517},
#  {'yad_no': 210,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 7,
#   'rate1': 0.75,
#   'rate2': 2.931313797167456},
#  {'yad_no': 211,
#   'train_log': 110,
#   'train_label': 76,
#   'test_log': 35,
#   'rate1': 0.6909090909090909,
#   'rate2': 0.5329661449395374},
#  {'yad_no': 212,
#   'train_log': 41,
#   'train_label': 38,
#   'test_log': 25,
#   'rate1': 0.926829268292683,
#   'rate2': 1.0213636923928417},
#  {'yad_no': 213,
#   'train_log': 52,
#   'train_label': 46,
#   'test_log': 46,
#   'rate1': 0.8846153846153846,
#   'rate2': 1.4817630183483843},
#  {'yad_no': 214,
#   'train_log': 12,
#   'train_label': 9,
#   'test_log': 10,
#   'rate1': 0.75,
#   'rate2': 1.3958637129368838},
#  {'yad_no': 215,
#   'train_log': 28,
#   'train_label': 16,
#   'test_log': 20,
#   'rate1': 0.5714285714285714,
#   'rate2': 1.1964546110887575},
#  {'yad_no': 216,
#   'train_log': 4,
#   'train_label': 4,
#   'test_log': 7,
#   'rate1': 1.0,
#   'rate2': 2.931313797167456},
#  {'yad_no': 217,
#   'train_log': 33,
#   'train_label': 18,
#   'test_log': 20,
#   'rate1': 0.5454545454545454,
#   'rate2': 1.0151736094086428},
#  {'yad_no': 218,
#   'train_log': 9,
#   'train_label': 14,
#   'test_log': 2,
#   'rate1': 1.5555555555555556,
#   'rate2': 0.37223032344983564},
#  {'yad_no': 219,
#   'train_log': 22,
#   'train_label': 22,
#   'test_log': 6,
#   'rate1': 1.0,
#   'rate2': 0.4568281242338892},
#  {'yad_no': 220,
#   'train_log': 7,
#   'train_label': 2,
#   'test_log': 4,
#   'rate1': 0.2857142857142857,
#   'rate2': 0.957163688871006},
#  {'yad_no': 221,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 222,
#   'train_log': 19,
#   'train_label': 22,
#   'test_log': 11,
#   'rate1': 1.1578947368421053,
#   'rate2': 0.9697579479350982},
#  {'yad_no': 223,
#   'train_log': 13,
#   'train_label': 18,
#   'test_log': 43,
#   'rate1': 1.3846153846153846,
#   'rate2': 5.540505199041784},
#  {'yad_no': 224,
#   'train_log': 207,
#   'train_label': 46,
#   'test_log': 9,
#   'rate1': 0.2222222222222222,
#   'rate2': 0.07282767197931567},
#  {'yad_no': 225,
#   'train_log': 28,
#   'train_label': 23,
#   'test_log': 18,
#   'rate1': 0.8214285714285714,
#   'rate2': 1.0768091499798818},
#  {'yad_no': 226,
#   'train_log': 16,
#   'train_label': 4,
#   'test_log': 11,
#   'rate1': 0.25,
#   'rate2': 1.151587563172929},
#  {'yad_no': 227,
#   'train_log': 5,
#   'train_label': 6,
#   'test_log': 3,
#   'rate1': 1.2,
#   'rate2': 1.0050218733145562},
#  {'yad_no': 228,
#   'train_log': 40,
#   'train_label': 39,
#   'test_log': 31,
#   'rate1': 0.975,
#   'rate2': 1.298153253031302},
#  {'yad_no': 229,
#   'train_log': 20,
#   'train_label': 19,
#   'test_log': 28,
#   'rate1': 0.95,
#   'rate2': 2.3450510377339646},
#  {'yad_no': 230,
#   'train_log': 20,
#   'train_label': 15,
#   'test_log': 5,
#   'rate1': 0.75,
#   'rate2': 0.4187591138810651},
#  {'yad_no': 231,
#   'train_log': 16,
#   'train_label': 21,
#   'test_log': 18,
#   'rate1': 1.3125,
#   'rate2': 1.884416012464793},
#  {'yad_no': 232,
#   'train_log': 12,
#   'train_label': 6,
#   'test_log': 8,
#   'rate1': 0.5,
#   'rate2': 1.116690970349507},
#  {'yad_no': 233,
#   'train_log': 65,
#   'train_label': 30,
#   'test_log': 34,
#   'rate1': 0.46153846153846156,
#   'rate2': 0.8761729151973056},
#  {'yad_no': 234,
#   'train_log': 22,
#   'train_label': 17,
#   'test_log': 16,
#   'rate1': 0.7727272727272727,
#   'rate2': 1.2182083312903713},
#  {'yad_no': 235,
#   'train_log': 9,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.3333333333333333,
#   'rate2': 0.37223032344983564},
#  {'yad_no': 236,
#   'train_log': 6,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 237,
#   'train_log': 16,
#   'train_label': 16,
#   'test_log': 9,
#   'rate1': 1.0,
#   'rate2': 0.9422080062323965},
#  {'yad_no': 238,
#   'train_log': 5,
#   'train_label': 3,
#   'test_log': 9,
#   'rate1': 0.6,
#   'rate2': 3.015065619943669},
#  {'yad_no': 239,
#   'train_log': 19,
#   'train_label': 18,
#   'test_log': 2,
#   'rate1': 0.9473684210526315,
#   'rate2': 0.17631962689729058},
#  {'yad_no': 240,
#   'train_log': 35,
#   'train_label': 26,
#   'test_log': 21,
#   'rate1': 0.7428571428571429,
#   'rate2': 1.0050218733145562},
#  {'yad_no': 241,
#   'train_log': 12,
#   'train_label': 9,
#   'test_log': 18,
#   'rate1': 0.75,
#   'rate2': 2.5125546832863908},
#  {'yad_no': 242,
#   'train_log': 8,
#   'train_label': 6,
#   'test_log': 5,
#   'rate1': 0.75,
#   'rate2': 1.0468977847026628},
#  {'yad_no': 243,
#   'train_log': 71,
#   'train_label': 47,
#   'test_log': 45,
#   'rate1': 0.6619718309859155,
#   'rate2': 1.0616428239238271},
#  {'yad_no': 244,
#   'train_log': 56,
#   'train_label': 51,
#   'test_log': 59,
#   'rate1': 0.9107142857142857,
#   'rate2': 1.7647705513559173},
#  {'yad_no': 245,
#   'train_log': 94,
#   'train_label': 100,
#   'test_log': 11,
#   'rate1': 1.0638297872340425,
#   'rate2': 0.19601490436986027},
#  {'yad_no': 246,
#   'train_log': 55,
#   'train_label': 21,
#   'test_log': 34,
#   'rate1': 0.38181818181818183,
#   'rate2': 1.0354770815968155},
#  {'yad_no': 247,
#   'train_log': 6,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.5,
#   'rate2': 1.3958637129368838},
#  {'yad_no': 248,
#   'train_log': 47,
#   'train_label': 37,
#   'test_log': 29,
#   'rate1': 0.7872340425531915,
#   'rate2': 1.0335331321319905},
#  {'yad_no': 249,
#   'train_log': 17,
#   'train_label': 6,
#   'test_log': 11,
#   'rate1': 0.35294117647058826,
#   'rate2': 1.083847118280404},
#  {'yad_no': 250,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 5,
#   'rate1': 1.3333333333333333,
#   'rate2': 2.7917274258737677},
#  {'yad_no': 251,
#   'train_log': 51,
#   'train_label': 54,
#   'test_log': 3,
#   'rate1': 1.0588235294117647,
#   'rate2': 0.09853155620730944},
#  {'yad_no': 252,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 253,
#   'train_log': 59,
#   'train_label': 44,
#   'test_log': 33,
#   'rate1': 0.7457627118644068,
#   'rate2': 0.9368847971576372},
#  {'yad_no': 254,
#   'train_log': 68,
#   'train_label': 48,
#   'test_log': 2,
#   'rate1': 0.7058823529411765,
#   'rate2': 0.04926577810365472},
#  {'yad_no': 255,
#   'train_log': 132,
#   'train_label': 74,
#   'test_log': 75,
#   'rate1': 0.5606060606060606,
#   'rate2': 0.9517252588206027},
#  {'yad_no': 256,
#   'train_log': 20,
#   'train_label': 16,
#   'test_log': 7,
#   'rate1': 0.8,
#   'rate2': 0.5862627594334912},
#  {'yad_no': 257,
#   'train_log': 10,
#   'train_label': 9,
#   'test_log': 10,
#   'rate1': 0.9,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 258,
#   'train_log': 5,
#   'train_label': 3,
#   'test_log': 3,
#   'rate1': 0.6,
#   'rate2': 1.0050218733145562},
#  {'yad_no': 259,
#   'train_log': 18,
#   'train_label': 10,
#   'test_log': 11,
#   'rate1': 0.5555555555555556,
#   'rate2': 1.0236333894870482},
#  {'yad_no': 260,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954},
#  {'yad_no': 261,
#   'train_log': 8,
#   'train_label': 5,
#   'test_log': 3,
#   'rate1': 0.625,
#   'rate2': 0.6281386708215977},
#  {'yad_no': 262,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 263,
#   'train_log': 28,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.17857142857142858,
#   'rate2': 0.11964546110887575},
#  {'yad_no': 264,
#   'train_log': 14,
#   'train_label': 11,
#   'test_log': 8,
#   'rate1': 0.7857142857142857,
#   'rate2': 0.957163688871006},
#  {'yad_no': 265,
#   'train_log': 24,
#   'train_label': 17,
#   'test_log': 19,
#   'rate1': 0.7083333333333334,
#   'rate2': 1.3260705272900395},
#  {'yad_no': 266,
#   'train_log': 28,
#   'train_label': 23,
#   'test_log': 24,
#   'rate1': 0.8214285714285714,
#   'rate2': 1.435745533306509},
#  {'yad_no': 267,
#   'train_log': 77,
#   'train_label': 32,
#   'test_log': 86,
#   'rate1': 0.4155844155844156,
#   'rate2': 1.8708199373387844},
#  {'yad_no': 268,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.75,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 269,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954},
#  {'yad_no': 270,
#   'train_log': 7,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.2857142857142857,
#   'rate2': 0.478581844435503},
#  {'yad_no': 271,
#   'train_log': 35,
#   'train_label': 19,
#   'test_log': 3,
#   'rate1': 0.5428571428571428,
#   'rate2': 0.1435745533306509},
#  {'yad_no': 272,
#   'train_log': 9,
#   'train_label': 5,
#   'test_log': 6,
#   'rate1': 0.5555555555555556,
#   'rate2': 1.116690970349507},
#  {'yad_no': 273,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 274,
#   'train_log': 2,
#   'train_label': 5,
#   'test_log': 3,
#   'rate1': 2.5,
#   'rate2': 2.5125546832863908},
#  {'yad_no': 275,
#   'train_log': 82,
#   'train_label': 61,
#   'test_log': 33,
#   'rate1': 0.7439024390243902,
#   'rate2': 0.6741000369792756},
#  {'yad_no': 276,
#   'train_log': 109,
#   'train_label': 57,
#   'test_log': 67,
#   'rate1': 0.5229357798165137,
#   'rate2': 1.0296095644048207},
#  {'yad_no': 277,
#   'train_log': 101,
#   'train_label': 72,
#   'test_log': 41,
#   'rate1': 0.7128712871287128,
#   'rate2': 0.67996529382668},
#  {'yad_no': 278,
#   'train_log': 20,
#   'train_label': 17,
#   'test_log': 4,
#   'rate1': 0.85,
#   'rate2': 0.3350072911048521},
#  {'yad_no': 279,
#   'train_log': 13,
#   'train_label': 14,
#   'test_log': 12,
#   'rate1': 1.0769230769230769,
#   'rate2': 1.5461874974070098},
#  {'yad_no': 280,
#   'train_log': 18,
#   'train_label': 16,
#   'test_log': 13,
#   'rate1': 0.8888888888888888,
#   'rate2': 1.209748551211966},
#  {'yad_no': 281,
#   'train_log': 57,
#   'train_label': 40,
#   'test_log': 41,
#   'rate1': 0.7017543859649122,
#   'rate2': 1.2048507837981524},
#  {'yad_no': 282,
#   'train_log': 30,
#   'train_label': 16,
#   'test_log': 17,
#   'rate1': 0.5333333333333333,
#   'rate2': 0.9491873247970809},
#  {'yad_no': 283,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.6700145822097042},
#  {'yad_no': 284,
#   'train_log': 6,
#   'train_label': 8,
#   'test_log': 3,
#   'rate1': 1.3333333333333333,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 285,
#   'train_log': 38,
#   'train_label': 25,
#   'test_log': 16,
#   'rate1': 0.6578947368421053,
#   'rate2': 0.7052785075891623},
#  {'yad_no': 286,
#   'train_log': 21,
#   'train_label': 19,
#   'test_log': 7,
#   'rate1': 0.9047619047619048,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 287,
#   'train_log': 6,
#   'train_label': 6,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 288,
#   'train_log': 67,
#   'train_label': 59,
#   'test_log': 30,
#   'rate1': 0.8805970149253731,
#   'rate2': 0.7500163233690719},
#  {'yad_no': 289,
#   'train_log': 38,
#   'train_label': 31,
#   'test_log': 43,
#   'rate1': 0.8157894736842105,
#   'rate2': 1.8954359891458736},
#  {'yad_no': 290,
#   'train_log': 31,
#   'train_label': 26,
#   'test_log': 6,
#   'rate1': 0.8387096774193549,
#   'rate2': 0.3242006042950182},
#  {'yad_no': 291,
#   'train_log': 41,
#   'train_label': 40,
#   'test_log': 63,
#   'rate1': 0.975609756097561,
#   'rate2': 2.5738365048299614},
#  {'yad_no': 292,
#   'train_log': 12,
#   'train_label': 3,
#   'test_log': 9,
#   'rate1': 0.25,
#   'rate2': 1.2562773416431954},
#  {'yad_no': 293,
#   'train_log': 6,
#   'train_label': 2,
#   'test_log': 11,
#   'rate1': 0.3333333333333333,
#   'rate2': 3.070900168461144},
#  {'yad_no': 294,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.75,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 295,
#   'train_log': 8,
#   'train_label': 4,
#   'test_log': 9,
#   'rate1': 0.5,
#   'rate2': 1.884416012464793},
#  {'yad_no': 296,
#   'train_log': 28,
#   'train_label': 22,
#   'test_log': 41,
#   'rate1': 0.7857142857142857,
#   'rate2': 2.452731952731953},
#  {'yad_no': 297,
#   'train_log': 38,
#   'train_label': 47,
#   'test_log': 5,
#   'rate1': 1.236842105263158,
#   'rate2': 0.22039953362161321},
#  {'yad_no': 298,
#   'train_log': 16,
#   'train_label': 13,
#   'test_log': 18,
#   'rate1': 0.8125,
#   'rate2': 1.884416012464793},
#  {'yad_no': 299,
#   'train_log': 31,
#   'train_label': 21,
#   'test_log': 27,
#   'rate1': 0.6774193548387096,
#   'rate2': 1.4589027193275816},
#  {'yad_no': 300,
#   'train_log': 10,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.2,
#   'rate2': 0.3350072911048521},
#  {'yad_no': 301,
#   'train_log': 41,
#   'train_label': 30,
#   'test_log': 48,
#   'rate1': 0.7317073170731707,
#   'rate2': 1.961018289394256},
#  {'yad_no': 302,
#   'train_log': 12,
#   'train_label': 6,
#   'test_log': 6,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 303,
#   'train_log': 10,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.3350072911048521},
#  {'yad_no': 304,
#   'train_log': 76,
#   'train_label': 45,
#   'test_log': 42,
#   'rate1': 0.5921052631578947,
#   'rate2': 0.9256780412107757},
#  {'yad_no': 305,
#   'train_log': 50,
#   'train_label': 21,
#   'test_log': 39,
#   'rate1': 0.42,
#   'rate2': 1.3065284353089233},
#  {'yad_no': 306,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 307,
#   'train_log': 296,
#   'train_label': 144,
#   'test_log': 160,
#   'rate1': 0.4864864864864865,
#   'rate2': 0.9054251110941949},
#  {'yad_no': 308,
#   'train_log': 22,
#   'train_label': 3,
#   'test_log': 4,
#   'rate1': 0.13636363636363635,
#   'rate2': 0.30455208282259283},
#  {'yad_no': 309,
#   'train_log': 19,
#   'train_label': 7,
#   'test_log': 3,
#   'rate1': 0.3684210526315789,
#   'rate2': 0.26447944034593585},
#  {'yad_no': 310,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.3333333333333333,
#   'rate2': 1.116690970349507},
#  {'yad_no': 311,
#   'train_log': 6,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.3333333333333333,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 312,
#   'train_log': 5,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.4,
#   'rate2': 0.6700145822097042},
#  {'yad_no': 313,
#   'train_log': 54,
#   'train_label': 65,
#   'test_log': 2,
#   'rate1': 1.2037037037037037,
#   'rate2': 0.06203838724163927},
#  {'yad_no': 314,
#   'train_log': 8,
#   'train_label': 4,
#   'test_log': 15,
#   'rate1': 0.5,
#   'rate2': 3.1406933541079884},
#  {'yad_no': 315,
#   'train_log': 20,
#   'train_label': 13,
#   'test_log': 16,
#   'rate1': 0.65,
#   'rate2': 1.3400291644194084},
#  {'yad_no': 316,
#   'train_log': 8,
#   'train_label': 7,
#   'test_log': 4,
#   'rate1': 0.875,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 317,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.75,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 318,
#   'train_log': 6,
#   'train_label': 4,
#   'test_log': 13,
#   'rate1': 0.6666666666666666,
#   'rate2': 3.6292456536358975},
#  {'yad_no': 319,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 24,
#   'rate1': 1.5,
#   'rate2': 20.100437466291126},
#  {'yad_no': 320,
#   'train_log': 28,
#   'train_label': 14,
#   'test_log': 12,
#   'rate1': 0.5,
#   'rate2': 0.7178727666532545},
#  {'yad_no': 321,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954},
#  {'yad_no': 322,
#   'train_log': 44,
#   'train_label': 31,
#   'test_log': 18,
#   'rate1': 0.7045454545454546,
#   'rate2': 0.6852421863508339},
#  {'yad_no': 323,
#   'train_log': 21,
#   'train_label': 16,
#   'test_log': 2,
#   'rate1': 0.7619047619047619,
#   'rate2': 0.15952728147850098},
#  {'yad_no': 324,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 7,
#   'rate1': 1.0,
#   'rate2': 3.908418396223275},
#  {'yad_no': 325,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 326,
#   'train_log': 7,
#   'train_label': 7,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.478581844435503},
#  {'yad_no': 327,
#   'train_log': 10,
#   'train_label': 7,
#   'test_log': 14,
#   'rate1': 0.7,
#   'rate2': 2.3450510377339646},
#  {'yad_no': 328,
#   'train_log': 11,
#   'train_label': 11,
#   'test_log': 16,
#   'rate1': 1.0,
#   'rate2': 2.4364166625807426},
#  {'yad_no': 329,
#   'train_log': 39,
#   'train_label': 30,
#   'test_log': 36,
#   'rate1': 0.7692307692307693,
#   'rate2': 1.5461874974070098},
#  {'yad_no': 330,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 18,
#   'rate1': 1.0,
#   'rate2': 6.030131239887338},
#  {'yad_no': 331,
#   'train_log': 84,
#   'train_label': 68,
#   'test_log': 85,
#   'rate1': 0.8095238095238095,
#   'rate2': 1.694977365709073},
#  {'yad_no': 332,
#   'train_log': 15,
#   'train_label': 5,
#   'test_log': 21,
#   'rate1': 0.3333333333333333,
#   'rate2': 2.3450510377339646},
#  {'yad_no': 333,
#   'train_log': 10,
#   'train_label': 6,
#   'test_log': 2,
#   'rate1': 0.6,
#   'rate2': 0.3350072911048521},
#  {'yad_no': 334,
#   'train_log': 17,
#   'train_label': 19,
#   'test_log': 6,
#   'rate1': 1.1176470588235294,
#   'rate2': 0.5911893372438567},
#  {'yad_no': 335,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 4,
#   'rate1': 1.3333333333333333,
#   'rate2': 2.233381940699014},
#  {'yad_no': 336,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 337,
#   'train_log': 27,
#   'train_label': 9,
#   'test_log': 7,
#   'rate1': 0.3333333333333333,
#   'rate2': 0.43426871069147494},
#  {'yad_no': 338,
#   'train_log': 10,
#   'train_label': 6,
#   'test_log': 4,
#   'rate1': 0.6,
#   'rate2': 0.6700145822097042},
#  {'yad_no': 339,
#   'train_log': 86,
#   'train_label': 57,
#   'test_log': 52,
#   'rate1': 0.6627906976744186,
#   'rate2': 1.0128127405495528},
#  {'yad_no': 340,
#   'train_log': 97,
#   'train_label': 70,
#   'test_log': 86,
#   'rate1': 0.7216494845360825,
#   'rate2': 1.4850838677843958},
#  {'yad_no': 341,
#   'train_log': 41,
#   'train_label': 24,
#   'test_log': 27,
#   'rate1': 0.5853658536585366,
#   'rate2': 1.1030727877842692},
#  {'yad_no': 342,
#   'train_log': 13,
#   'train_label': 11,
#   'test_log': 6,
#   'rate1': 0.8461538461538461,
#   'rate2': 0.7730937487035049},
#  {'yad_no': 343,
#   'train_log': 100,
#   'train_label': 72,
#   'test_log': 14,
#   'rate1': 0.72,
#   'rate2': 0.2345051037733965},
#  {'yad_no': 344,
#   'train_log': 15,
#   'train_label': 19,
#   'test_log': 13,
#   'rate1': 1.2666666666666666,
#   'rate2': 1.4516982614543592},
#  {'yad_no': 345,
#   'train_log': 7,
#   'train_label': 8,
#   'test_log': 6,
#   'rate1': 1.1428571428571428,
#   'rate2': 1.435745533306509},
#  {'yad_no': 346,
#   'train_log': 6,
#   'train_label': 3,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 347,
#   'train_log': 32,
#   'train_label': 28,
#   'test_log': 19,
#   'rate1': 0.875,
#   'rate2': 0.9945528954675297},
#  {'yad_no': 348,
#   'train_log': 77,
#   'train_label': 51,
#   'test_log': 33,
#   'rate1': 0.6623376623376623,
#   'rate2': 0.7178727666532545},
#  {'yad_no': 349,
#   'train_log': 15,
#   'train_label': 13,
#   'test_log': 15,
#   'rate1': 0.8666666666666667,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 350,
#   'train_log': 6,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.3333333333333333,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 351,
#   'train_log': 24,
#   'train_label': 16,
#   'test_log': 16,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 352,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 353,
#   'train_log': 28,
#   'train_label': 19,
#   'test_log': 15,
#   'rate1': 0.6785714285714286,
#   'rate2': 0.8973409583165681},
#  {'yad_no': 354,
#   'train_log': 38,
#   'train_label': 31,
#   'test_log': 11,
#   'rate1': 0.8157894736842105,
#   'rate2': 0.4848789739675491},
#  {'yad_no': 355,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.75,
#   'rate2': 2.0937955694053256},
#  {'yad_no': 356,
#   'train_log': 16,
#   'train_label': 10,
#   'test_log': 15,
#   'rate1': 0.625,
#   'rate2': 1.5703466770539942},
#  {'yad_no': 357,
#   'train_log': 112,
#   'train_label': 70,
#   'test_log': 59,
#   'rate1': 0.625,
#   'rate2': 0.8823852756779587},
#  {'yad_no': 358,
#   'train_log': 34,
#   'train_label': 26,
#   'test_log': 17,
#   'rate1': 0.7647058823529411,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 359,
#   'train_log': 28,
#   'train_label': 24,
#   'test_log': 11,
#   'rate1': 0.8571428571428571,
#   'rate2': 0.6580500360988166},
#  {'yad_no': 360,
#   'train_log': 25,
#   'train_label': 27,
#   'test_log': 8,
#   'rate1': 1.08,
#   'rate2': 0.5360116657677634},
#  {'yad_no': 361,
#   'train_log': 7,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.7142857142857143,
#   'rate2': 0.478581844435503},
#  {'yad_no': 362,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 1.5,
#   'rate2': 4.187591138810651},
#  {'yad_no': 363,
#   'train_log': 5,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.4,
#   'rate2': 0.6700145822097042},
#  {'yad_no': 364,
#   'train_log': 76,
#   'train_label': 40,
#   'test_log': 34,
#   'rate1': 0.5263157894736842,
#   'rate2': 0.7493584143134849},
#  {'yad_no': 365,
#   'train_log': 17,
#   'train_label': 4,
#   'test_log': 18,
#   'rate1': 0.23529411764705882,
#   'rate2': 1.77356801173157},
#  {'yad_no': 366,
#   'train_log': 15,
#   'train_label': 7,
#   'test_log': 8,
#   'rate1': 0.4666666666666667,
#   'rate2': 0.8933527762796056},
#  {'yad_no': 367,
#   'train_log': 7,
#   'train_label': 4,
#   'test_log': 3,
#   'rate1': 0.5714285714285714,
#   'rate2': 0.7178727666532545},
#  {'yad_no': 368,
#   'train_log': 75,
# ...
#   'rate1': 0.5104895104895105,
#   'rate2': 1.698463538818306},
#  {'yad_no': 879,
#   'train_log': 23,
#   'train_label': 22,
#   'test_log': 7,
#   'rate1': 0.9565217391304348,
#   'rate2': 0.5097937038552097},
#  {'yad_no': 880,
#   'train_log': 7,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.2857142857142857,
#   'rate2': 0.7178727666532545},
#  {'yad_no': 881,
#   'train_log': 12,
#   'train_label': 7,
#   'test_log': 7,
#   'rate1': 0.5833333333333334,
#   'rate2': 0.9771045990558187},
#  {'yad_no': 882,
#   'train_log': 3,
#   'train_label': 5,
#   'test_log': 5,
#   'rate1': 1.6666666666666667,
#   'rate2': 2.7917274258737677},
#  {'yad_no': 883,
#   'train_log': 6,
#   'train_label': 8,
#   'test_log': 9,
#   'rate1': 1.3333333333333333,
#   'rate2': 2.5125546832863908},
#  {'yad_no': 884,
#   'train_log': 11,
#   'train_label': 13,
#   'test_log': 18,
#   'rate1': 1.1818181818181819,
#   'rate2': 2.7409687454033356},
#  {'yad_no': 885,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 5,
#   'rate1': 0.5,
#   'rate2': 2.0937955694053256},
#  {'yad_no': 886,
#   'train_log': 10,
#   'train_label': 13,
#   'test_log': 7,
#   'rate1': 1.3,
#   'rate2': 1.1725255188669823},
#  {'yad_no': 887,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.6700145822097042},
#  {'yad_no': 888,
#   'train_log': 21,
#   'train_label': 14,
#   'test_log': 3,
#   'rate1': 0.6666666666666666,
#   'rate2': 0.2392909222177515},
#  {'yad_no': 889,
#   'train_log': 6,
#   'train_label': 5,
#   'test_log': 18,
#   'rate1': 0.8333333333333334,
#   'rate2': 5.0251093665727815},
#  {'yad_no': 890,
#   'train_log': 18,
#   'train_label': 5,
#   'test_log': 28,
#   'rate1': 0.2777777777777778,
#   'rate2': 2.6056122641488497},
#  {'yad_no': 891,
#   'train_log': 103,
#   'train_label': 87,
#   'test_log': 79,
#   'rate1': 0.8446601941747572,
#   'rate2': 1.2847366988972484},
#  {'yad_no': 892,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 893,
#   'train_log': 6,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.5,
#   'rate2': 1.3958637129368838},
#  {'yad_no': 894,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 4,
#   'rate1': 0.6666666666666666,
#   'rate2': 2.233381940699014},
#  {'yad_no': 895,
#   'train_log': 99,
#   'train_label': 81,
#   'test_log': 78,
#   'rate1': 0.8181818181818182,
#   'rate2': 1.3197256922312355},
#  {'yad_no': 896,
#   'train_log': 17,
#   'train_label': 7,
#   'test_log': 8,
#   'rate1': 0.4117647058823529,
#   'rate2': 0.7882524496584755},
#  {'yad_no': 897,
#   'train_log': 31,
#   'train_label': 22,
#   'test_log': 17,
#   'rate1': 0.7096774193548387,
#   'rate2': 0.9185683788358847},
#  {'yad_no': 898,
#   'train_log': 108,
#   'train_label': 73,
#   'test_log': 58,
#   'rate1': 0.6759259259259259,
#   'rate2': 0.8995566150037696},
#  {'yad_no': 899,
#   'train_log': 70,
#   'train_label': 33,
#   'test_log': 36,
#   'rate1': 0.4714285714285714,
#   'rate2': 0.8614473199839053},
#  {'yad_no': 900,
#   'train_log': 13,
#   'train_label': 17,
#   'test_log': 3,
#   'rate1': 1.3076923076923077,
#   'rate2': 0.38654687435175245},
#  {'yad_no': 901,
#   'train_log': 47,
#   'train_label': 40,
#   'test_log': 21,
#   'rate1': 0.851063829787234,
#   'rate2': 0.7484205439576482},
#  {'yad_no': 902,
#   'train_log': 100,
#   'train_label': 57,
#   'test_log': 58,
#   'rate1': 0.57,
#   'rate2': 0.971521144204071},
#  {'yad_no': 903,
#   'train_log': 2,
#   'train_label': 8,
#   'test_log': 15,
#   'rate1': 4.0,
#   'rate2': 12.562773416431954},
#  {'yad_no': 904,
#   'train_log': 25,
#   'train_label': 21,
#   'test_log': 3,
#   'rate1': 0.84,
#   'rate2': 0.20100437466291124},
#  {'yad_no': 905,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 7,
#   'rate1': 1.5,
#   'rate2': 5.862627594334912},
#  {'yad_no': 906,
#   'train_log': 79,
#   'train_label': 55,
#   'test_log': 42,
#   'rate1': 0.6962025316455697,
#   'rate2': 0.8905257105318852},
#  {'yad_no': 907,
#   'train_log': 14,
#   'train_label': 9,
#   'test_log': 3,
#   'rate1': 0.6428571428571429,
#   'rate2': 0.35893638332662725},
#  {'yad_no': 908,
#   'train_log': 21,
#   'train_label': 19,
#   'test_log': 18,
#   'rate1': 0.9047619047619048,
#   'rate2': 1.435745533306509},
#  {'yad_no': 909,
#   'train_log': 46,
#   'train_label': 43,
#   'test_log': 8,
#   'rate1': 0.9347826086956522,
#   'rate2': 0.29131068791726267},
#  {'yad_no': 910,
#   'train_log': 25,
#   'train_label': 35,
#   'test_log': 8,
#   'rate1': 1.4,
#   'rate2': 0.5360116657677634},
#  {'yad_no': 911,
#   'train_log': 7,
#   'train_label': 2,
#   'test_log': 7,
#   'rate1': 0.2857142857142857,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 912,
#   'train_log': 50,
#   'train_label': 26,
#   'test_log': 50,
#   'rate1': 0.52,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 913,
#   'train_log': 9,
#   'train_label': 5,
#   'test_log': 7,
#   'rate1': 0.5555555555555556,
#   'rate2': 1.3028061320744249},
#  {'yad_no': 914,
#   'train_log': 54,
#   'train_label': 22,
#   'test_log': 2,
#   'rate1': 0.4074074074074074,
#   'rate2': 0.06203838724163927},
#  {'yad_no': 915,
#   'train_log': 754,
#   'train_label': 244,
#   'test_log': 347,
#   'rate1': 0.32360742705570295,
#   'rate2': 0.7708722149428626},
#  {'yad_no': 916,
#   'train_log': 17,
#   'train_label': 14,
#   'test_log': 6,
#   'rate1': 0.8235294117647058,
#   'rate2': 0.5911893372438567},
#  {'yad_no': 917,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 918,
#   'train_log': 59,
#   'train_label': 33,
#   'test_log': 84,
#   'rate1': 0.559322033898305,
#   'rate2': 2.3847976654921674},
#  {'yad_no': 919,
#   'train_log': 29,
#   'train_label': 28,
#   'test_log': 15,
#   'rate1': 0.9655172413793104,
#   'rate2': 0.8663981666504796},
#  {'yad_no': 920,
#   'train_log': 6,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.3333333333333333,
#   'rate2': 0.5583454851747535},
#  {'yad_no': 921,
#   'train_log': 190,
#   'train_label': 110,
#   'test_log': 49,
#   'rate1': 0.5789473684210527,
#   'rate2': 0.431983085898362},
#  {'yad_no': 922,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 3,
#   'rate1': 1.0,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 923,
#   'train_log': 6,
#   'train_label': 4,
#   'test_log': 4,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507},
#  {'yad_no': 924,
#   'train_log': 81,
#   'train_label': 63,
#   'test_log': 3,
#   'rate1': 0.7777777777777778,
#   'rate2': 0.06203838724163927},
#  {'yad_no': 925,
#   'train_log': 61,
#   'train_label': 74,
#   'test_log': 34,
#   'rate1': 1.2131147540983607,
#   'rate2': 0.9336268768495878},
#  {'yad_no': 926,
#   'train_log': 65,
#   'train_label': 30,
#   'test_log': 39,
#   'rate1': 0.46153846153846156,
#   'rate2': 1.0050218733145562},
#  {'yad_no': 927,
#   'train_log': 9,
#   'train_label': 8,
#   'test_log': 17,
#   'rate1': 0.8888888888888888,
#   'rate2': 3.163957749323603},
#  {'yad_no': 928,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 929,
#   'train_log': 17,
#   'train_label': 15,
#   'test_log': 6,
#   'rate1': 0.8823529411764706,
#   'rate2': 0.5911893372438567},
#  {'yad_no': 930,
#   'train_log': 69,
#   'train_label': 23,
#   'test_log': 35,
#   'rate1': 0.3333333333333333,
#   'rate2': 0.8496561730920162},
#  {'yad_no': 931,
#   'train_log': 67,
#   'train_label': 33,
#   'test_log': 49,
#   'rate1': 0.4925373134328358,
#   'rate2': 1.2250266615028174},
#  {'yad_no': 932,
#   'train_log': 12,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.25,
#   'rate2': 0.27917274258737673},
#  {'yad_no': 933,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 934,
#   'train_log': 25,
#   'train_label': 13,
#   'test_log': 25,
#   'rate1': 0.52,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 935,
#   'train_log': 78,
#   'train_label': 52,
#   'test_log': 65,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.3958637129368838},
#  {'yad_no': 936,
#   'train_log': 6,
#   'train_label': 6,
#   'test_log': 7,
#   'rate1': 1.0,
#   'rate2': 1.9542091981116374},
#  {'yad_no': 937,
#   'train_log': 15,
#   'train_label': 9,
#   'test_log': 19,
#   'rate1': 0.6,
#   'rate2': 2.121712843664063},
#  {'yad_no': 938,
#   'train_log': 17,
#   'train_label': 10,
#   'test_log': 10,
#   'rate1': 0.5882352941176471,
#   'rate2': 0.9853155620730945},
#  {'yad_no': 939,
#   'train_log': 18,
#   'train_label': 16,
#   'test_log': 13,
#   'rate1': 0.8888888888888888,
#   'rate2': 1.209748551211966},
#  {'yad_no': 940,
#   'train_log': 4,
#   'train_label': 9,
#   'test_log': 5,
#   'rate1': 2.25,
#   'rate2': 2.0937955694053256},
#  {'yad_no': 941,
#   'train_log': 73,
#   'train_label': 52,
#   'test_log': 61,
#   'rate1': 0.7123287671232876,
#   'rate2': 1.3996879970819163},
#  {'yad_no': 942,
#   'train_log': 7,
#   'train_label': 6,
#   'test_log': 8,
#   'rate1': 0.8571428571428571,
#   'rate2': 1.914327377742012},
#  {'yad_no': 943,
#   'train_log': 101,
#   'train_label': 66,
#   'test_log': 37,
#   'rate1': 0.6534653465346535,
#   'rate2': 0.6136272163801746},
#  {'yad_no': 944,
#   'train_log': 4,
#   'train_label': 4,
#   'test_log': 17,
#   'rate1': 1.0,
#   'rate2': 7.118904935978107},
#  {'yad_no': 945,
#   'train_log': 80,
#   'train_label': 53,
#   'test_log': 49,
#   'rate1': 0.6625,
#   'rate2': 1.0259598290086096},
#  {'yad_no': 946,
#   'train_log': 11,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.18181818181818182,
#   'rate2': 0.4568281242338892},
#  {'yad_no': 947,
#   'train_log': 2,
#   'train_label': 4,
#   'test_log': 14,
#   'rate1': 2.0,
#   'rate2': 11.725255188669824},
#  {'yad_no': 948,
#   'train_log': 4,
#   'train_label': 7,
#   'test_log': 2,
#   'rate1': 1.75,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 949,
#   'train_log': 22,
#   'train_label': 13,
#   'test_log': 12,
#   'rate1': 0.5909090909090909,
#   'rate2': 0.9136562484677784},
#  {'yad_no': 950,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 22,
#   'rate1': 1.0,
#   'rate2': 12.283600673844576},
#  {'yad_no': 951,
#   'train_log': 57,
#   'train_label': 51,
#   'test_log': 21,
#   'rate1': 0.8947368421052632,
#   'rate2': 0.617118694140517},
#  {'yad_no': 952,
#   'train_log': 45,
#   'train_label': 44,
#   'test_log': 52,
#   'rate1': 0.9777777777777777,
#   'rate2': 1.9355976819391454},
#  {'yad_no': 953,
#   'train_log': 2,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 2.0,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 954,
#   'train_log': 66,
#   'train_label': 68,
#   'test_log': 38,
#   'rate1': 1.0303030303030303,
#   'rate2': 0.9644149289382107},
#  {'yad_no': 955,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 7,
#   'rate1': 1.5,
#   'rate2': 5.862627594334912},
#  {'yad_no': 956,
#   'train_log': 6,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.5,
#   'rate2': 1.3958637129368838},
#  {'yad_no': 957,
#   'train_log': 79,
#   'train_label': 62,
#   'test_log': 48,
#   'rate1': 0.7848101265822784,
#   'rate2': 1.0177436691792976},
#  {'yad_no': 958,
#   'train_log': 8,
#   'train_label': 5,
#   'test_log': 16,
#   'rate1': 0.625,
#   'rate2': 3.350072911048521},
#  {'yad_no': 959,
#   'train_log': 29,
#   'train_label': 12,
#   'test_log': 17,
#   'rate1': 0.41379310344827586,
#   'rate2': 0.9819179222038767},
#  {'yad_no': 960,
#   'train_log': 26,
#   'train_label': 32,
#   'test_log': 3,
#   'rate1': 1.2307692307692308,
#   'rate2': 0.19327343717587622},
#  {'yad_no': 961,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.75,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 962,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954},
#  {'yad_no': 963,
#   'train_log': 24,
#   'train_label': 18,
#   'test_log': 20,
#   'rate1': 0.75,
#   'rate2': 1.3958637129368838},
#  {'yad_no': 964,
#   'train_log': 39,
#   'train_label': 36,
#   'test_log': 11,
#   'rate1': 0.9230769230769231,
#   'rate2': 0.472446179763253},
#  {'yad_no': 965,
#   'train_log': 19,
#   'train_label': 15,
#   'test_log': 16,
#   'rate1': 0.7894736842105263,
#   'rate2': 1.4105570151783247},
#  {'yad_no': 966,
#   'train_log': 65,
#   'train_label': 34,
#   'test_log': 59,
#   'rate1': 0.5230769230769231,
#   'rate2': 1.5204177057835595},
#  {'yad_no': 967,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.3333333333333333,
#   'rate2': 1.116690970349507},
#  {'yad_no': 968,
#   'train_log': 37,
#   'train_label': 26,
#   'test_log': 19,
#   'rate1': 0.7027027027027027,
#   'rate2': 0.8601538555394851},
#  {'yad_no': 969,
#   'train_log': 68,
#   'train_label': 60,
#   'test_log': 62,
#   'rate1': 0.8823529411764706,
#   'rate2': 1.5272391212132963},
#  {'yad_no': 970,
#   'train_log': 2,
#   'train_label': 6,
#   'test_log': 9,
#   'rate1': 3.0,
#   'rate2': 7.537664049859172},
#  {'yad_no': 971,
#   'train_log': 46,
#   'train_label': 35,
#   'test_log': 33,
#   'rate1': 0.7608695652173914,
#   'rate2': 1.2016565876587086},
#  {'yad_no': 972,
#   'train_log': 11,
#   'train_label': 7,
#   'test_log': 12,
#   'rate1': 0.6363636363636364,
#   'rate2': 1.8273124969355568},
#  {'yad_no': 973,
#   'train_log': 29,
#   'train_label': 18,
#   'test_log': 23,
#   'rate1': 0.6206896551724138,
#   'rate2': 1.3284771888640687},
#  {'yad_no': 974,
#   'train_log': 10,
#   'train_label': 10,
#   'test_log': 16,
#   'rate1': 1.0,
#   'rate2': 2.680058328838817},
#  {'yad_no': 975,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 976,
#   'train_log': 18,
#   'train_label': 19,
#   'test_log': 9,
#   'rate1': 1.0555555555555556,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 977,
#   'train_log': 8,
#   'train_label': 7,
#   'test_log': 33,
#   'rate1': 0.875,
#   'rate2': 6.909525379037575},
#  {'yad_no': 978,
#   'train_log': 13,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.38461538461538464,
#   'rate2': 0.2576979162345016},
#  {'yad_no': 979,
#   'train_log': 28,
#   'train_label': 19,
#   'test_log': 13,
#   'rate1': 0.6785714285714286,
#   'rate2': 0.7776954972076924},
#  {'yad_no': 980,
#   'train_log': 21,
#   'train_label': 17,
#   'test_log': 41,
#   'rate1': 0.8095238095238095,
#   'rate2': 3.27030927030927},
#  {'yad_no': 981,
#   'train_log': 24,
#   'train_label': 17,
#   'test_log': 23,
#   'rate1': 0.7083333333333334,
#   'rate2': 1.6052432698774164},
#  {'yad_no': 982,
#   'train_log': 18,
#   'train_label': 15,
#   'test_log': 12,
#   'rate1': 0.8333333333333334,
#   'rate2': 1.116690970349507},
#  {'yad_no': 983,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 10,
#   'rate1': 0.75,
#   'rate2': 4.187591138810651},
#  {'yad_no': 984,
#   'train_log': 7,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.42857142857142855,
#   'rate2': 0.478581844435503},
#  {'yad_no': 985,
#   'train_log': 9,
#   'train_label': 7,
#   'test_log': 11,
#   'rate1': 0.7777777777777778,
#   'rate2': 2.0472667789740964},
#  {'yad_no': 986,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 1.116690970349507},
#  {'yad_no': 987,
#   'train_log': 14,
#   'train_label': 9,
#   'test_log': 4,
#   'rate1': 0.6428571428571429,
#   'rate2': 0.478581844435503},
#  {'yad_no': 988,
#   'train_log': 8,
#   'train_label': 4,
#   'test_log': 5,
#   'rate1': 0.5,
#   'rate2': 1.0468977847026628},
#  {'yad_no': 989,
#   'train_log': 55,
#   'train_label': 48,
#   'test_log': 40,
#   'rate1': 0.8727272727272727,
#   'rate2': 1.2182083312903713},
#  {'yad_no': 990,
#   'train_log': 62,
#   'train_label': 38,
#   'test_log': 35,
#   'rate1': 0.6129032258064516,
#   'rate2': 0.9455850958604697},
#  {'yad_no': 991,
#   'train_log': 7,
#   'train_label': 7,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.478581844435503},
#  {'yad_no': 992,
#   'train_log': 11,
#   'train_label': 6,
#   'test_log': 2,
#   'rate1': 0.5454545454545454,
#   'rate2': 0.30455208282259283},
#  {'yad_no': 993,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303},
#  {'yad_no': 994,
#   'train_log': 16,
#   'train_label': 14,
#   'test_log': 17,
#   'rate1': 0.875,
#   'rate2': 1.7797262339945268},
#  {'yad_no': 995,
#   'train_log': 7,
#   'train_label': 5,
#   'test_log': 5,
#   'rate1': 0.7142857142857143,
#   'rate2': 1.1964546110887575},
#  {'yad_no': 996,
#   'train_log': 38,
#   'train_label': 26,
#   'test_log': 47,
#   'rate1': 0.6842105263157895,
#   'rate2': 2.0717556160431645},
#  {'yad_no': 997,
#   'train_log': 39,
#   'train_label': 35,
#   'test_log': 38,
#   'rate1': 0.8974358974358975,
#   'rate2': 1.6320868028185103},
#  {'yad_no': 998,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 999,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 4,
#   'rate1': 0.6666666666666666,
#   'rate2': 2.233381940699014},
#  ...]

# %%
# train -> test で 減っているもの
decrease_yado = sorted(each_counts, key=lambda x: x['rate2'])
# decrease_yado = [data for data in decrease_yado if data['rate2'] != 0.0]

# %% [markdown]
# ## 宿のタイプ：ビジネスと観光

# %%
yad_type = pd.read_csv("data/yado_with_count.csv")

for _, row in yad_type.iterrows():
    yad_no, yad_class = row[1], row[14]
    each_counts[yad_no]['yad_class'] = yad_class

each_counts
# Out:
# /var/folders/6k/nrp954t51fq50vv_ch4k2wc00000gn/T/ipykernel_649/3048806074.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   yad_no, yad_class = row[1], row[14]
# [{'yad_no': 0,
#   'train_log': 2,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 1.6750364555242605},
#  {'yad_no': 1,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 32,
#   'rate1': 1.5,
#   'rate2': 26.800583288388168,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 2,
#   'train_log': 26,
#   'train_label': 16,
#   'test_log': 7,
#   'rate1': 0.6153846153846154,
#   'rate2': 0.4509713534103778,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 3,
#   'train_log': 182,
#   'train_label': 96,
#   'test_log': 32,
#   'rate1': 0.5274725274725275,
#   'rate2': 0.2945119042680019,
#   'yad_class': '観光'},
#  {'yad_no': 4,
#   'train_log': 52,
#   'train_label': 36,
#   'test_log': 19,
#   'rate1': 0.6923076923076923,
#   'rate2': 0.6120325510569413,
#   'yad_class': '観光'},
#  {'yad_no': 5,
#   'train_log': 32,
#   'train_label': 22,
#   'test_log': 2,
#   'rate1': 0.6875,
#   'rate2': 0.10468977847026628,
#   'yad_class': '観光'},
#  {'yad_no': 6,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.75,
#   'rate2': 2.0937955694053256,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 7,
#   'train_log': 24,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.16666666666666666,
#   'rate2': 0.13958637129368837,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 8,
#   'train_log': 2,
#   'train_label': 7,
#   'test_log': 3,
#   'rate1': 3.5,
#   'rate2': 2.5125546832863908,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 9,
#   'train_log': 30,
#   'train_label': 27,
#   'test_log': 10,
#   'rate1': 0.9,
#   'rate2': 0.5583454851747535,
#   'yad_class': '観光'},
#  {'yad_no': 10,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954,
#   'yad_class': '0'},
#  {'yad_no': 11,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 1.116690970349507,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 12,
#   'train_log': 10,
#   'train_label': 3,
#   'test_log': 4,
#   'rate1': 0.3,
#   'rate2': 0.6700145822097042,
#   'yad_class': '観光'},
#  {'yad_no': 13,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954,
#   'yad_class': '0'},
#  {'yad_no': 14,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 15,
#   'train_log': 6,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.8333333333333334,
#   'rate2': 0.5583454851747535,
#   'yad_class': '観光'},
#  {'yad_no': 16,
#   'train_log': 14,
#   'train_label': 7,
#   'test_log': 7,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 17,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.75,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 18,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 4,
#   'rate1': 0.5,
#   'rate2': 1.6750364555242605,
#   'yad_class': '0'},
#  {'yad_no': 19,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954,
#   'yad_class': '0'},
#  {'yad_no': 20,
#   'train_log': 7,
#   'train_label': 4,
#   'test_log': 5,
#   'rate1': 0.5714285714285714,
#   'rate2': 1.1964546110887575,
#   'yad_class': '観光'},
#  {'yad_no': 21,
#   'train_log': 11,
#   'train_label': 7,
#   'test_log': 25,
#   'rate1': 0.6363636363636364,
#   'rate2': 3.8069010352824106,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 22,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 23,
#   'train_log': 83,
#   'train_label': 52,
#   'test_log': 45,
#   'rate1': 0.6265060240963856,
#   'rate2': 0.9081522951637556,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 24,
#   'train_log': 38,
#   'train_label': 16,
#   'test_log': 38,
#   'rate1': 0.42105263157894735,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 25,
#   'train_log': 57,
#   'train_label': 45,
#   'test_log': 53,
#   'rate1': 0.7894736842105263,
#   'rate2': 1.5574900375927334,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 26,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.3333333333333333,
#   'rate2': 1.116690970349507,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 27,
#   'train_log': 16,
#   'train_label': 17,
#   'test_log': 2,
#   'rate1': 1.0625,
#   'rate2': 0.20937955694053256,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 28,
#   'train_log': 130,
#   'train_label': 100,
#   'test_log': 93,
#   'rate1': 0.7692307692307693,
#   'rate2': 1.1982953104904326,
#   'yad_class': '観光'},
#  {'yad_no': 29,
#   'train_log': 7,
#   'train_label': 6,
#   'test_log': 5,
#   'rate1': 0.8571428571428571,
#   'rate2': 1.1964546110887575,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 30,
#   'train_log': 15,
#   'train_label': 9,
#   'test_log': 7,
#   'rate1': 0.6,
#   'rate2': 0.7816836792446549,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 31,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.75,
#   'rate2': 2.0937955694053256,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 32,
#   'train_log': 58,
#   'train_label': 57,
#   'test_log': 16,
#   'rate1': 0.9827586206896551,
#   'rate2': 0.4620790222135891,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 33,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 4,
#   'rate1': 0.8,
#   'rate2': 1.3400291644194084,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 34,
#   'train_log': 29,
#   'train_label': 13,
#   'test_log': 10,
#   'rate1': 0.4482758620689655,
#   'rate2': 0.5775987777669864,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 35,
#   'train_log': 25,
#   'train_label': 16,
#   'test_log': 7,
#   'rate1': 0.64,
#   'rate2': 0.469010207546793,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 36,
#   'train_log': 11,
#   'train_label': 12,
#   'test_log': 5,
#   'rate1': 1.0909090909090908,
#   'rate2': 0.761380207056482,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 37,
#   'train_log': 13,
#   'train_label': 17,
#   'test_log': 80,
#   'rate1': 1.3076923076923077,
#   'rate2': 10.307916649380065,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 38,
#   'train_log': 25,
#   'train_label': 21,
#   'test_log': 19,
#   'rate1': 0.84,
#   'rate2': 1.273027706198438,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 39,
#   'train_log': 61,
#   'train_label': 38,
#   'test_log': 34,
#   'rate1': 0.6229508196721312,
#   'rate2': 0.9336268768495878,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 40,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.75,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 41,
#   'train_log': 6,
#   'train_label': 5,
#   'test_log': 4,
#   'rate1': 0.8333333333333334,
#   'rate2': 1.116690970349507,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 42,
#   'train_log': 8,
#   'train_label': 3,
#   'test_log': 10,
#   'rate1': 0.375,
#   'rate2': 2.0937955694053256,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 43,
#   'train_log': 124,
#   'train_label': 55,
#   'test_log': 32,
#   'rate1': 0.4435483870967742,
#   'rate2': 0.43226747239335755,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 44,
#   'train_log': 22,
#   'train_label': 13,
#   'test_log': 6,
#   'rate1': 0.5909090909090909,
#   'rate2': 0.4568281242338892,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 45,
#   'train_log': 31,
#   'train_label': 21,
#   'test_log': 38,
#   'rate1': 0.6774193548387096,
#   'rate2': 2.0532704938684483,
#   'yad_class': '観光'},
#  {'yad_no': 46,
#   'train_log': 36,
#   'train_label': 17,
#   'test_log': 32,
#   'rate1': 0.4722222222222222,
#   'rate2': 1.4889212937993426,
#   'yad_class': '観光'},
#  {'yad_no': 47,
#   'train_log': 82,
#   'train_label': 82,
#   'test_log': 57,
#   'rate1': 1.0,
#   'rate2': 1.1643546093278396,
#   'yad_class': '観光'},
#  {'yad_no': 48,
#   'train_log': 4,
#   'train_label': 6,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 49,
#   'train_log': 42,
#   'train_label': 24,
#   'test_log': 31,
#   'rate1': 0.5714285714285714,
#   'rate2': 1.236336431458383,
#   'yad_class': '観光'},
#  {'yad_no': 50,
#   'train_log': 69,
#   'train_label': 41,
#   'test_log': 32,
#   'rate1': 0.5942028985507246,
#   'rate2': 0.7768285011127005,
#   'yad_class': '観光'},
#  {'yad_no': 51,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 3,
#   'rate1': 1.0,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 52,
#   'train_log': 45,
#   'train_label': 40,
#   'test_log': 16,
#   'rate1': 0.8888888888888888,
#   'rate2': 0.595568517519737,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 53,
#   'train_log': 5,
#   'train_label': 2,
#   'test_log': 6,
#   'rate1': 0.4,
#   'rate2': 2.0100437466291123,
#   'yad_class': '0'},
#  {'yad_no': 54,
#   'train_log': 24,
#   'train_label': 13,
#   'test_log': 47,
#   'rate1': 0.5416666666666666,
#   'rate2': 3.2802797254016767,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 55,
#   'train_log': 35,
#   'train_label': 24,
#   'test_log': 20,
#   'rate1': 0.6857142857142857,
#   'rate2': 0.957163688871006,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 56,
#   'train_log': 29,
#   'train_label': 28,
#   'test_log': 25,
#   'rate1': 0.9655172413793104,
#   'rate2': 1.4439969444174658,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 57,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303,
#   'yad_class': '0'},
#  {'yad_no': 58,
#   'train_log': 7,
#   'train_label': 10,
#   'test_log': 14,
#   'rate1': 1.4285714285714286,
#   'rate2': 3.350072911048521,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 59,
#   'train_log': 6,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 0.5583454851747535,
#   'yad_class': '観光'},
#  {'yad_no': 60,
#   'train_log': 12,
#   'train_label': 15,
#   'test_log': 12,
#   'rate1': 1.25,
#   'rate2': 1.6750364555242605,
#   'yad_class': '観光'},
#  {'yad_no': 61,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 5,
#   'rate1': 0.8,
#   'rate2': 1.6750364555242605,
#   'yad_class': '観光'},
#  {'yad_no': 62,
#   'train_log': 98,
#   'train_label': 92,
#   'test_log': 94,
#   'rate1': 0.9387755102040817,
#   'rate2': 1.6066676206049029,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 63,
#   'train_log': 46,
#   'train_label': 44,
#   'test_log': 22,
#   'rate1': 0.9565217391304348,
#   'rate2': 0.8011043917724724,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 64,
#   'train_log': 5,
#   'train_label': 2,
#   'test_log': 17,
#   'rate1': 0.4,
#   'rate2': 5.695123948782485,
#   'yad_class': '0'},
#  {'yad_no': 65,
#   'train_log': 24,
#   'train_label': 29,
#   'test_log': 22,
#   'rate1': 1.2083333333333333,
#   'rate2': 1.535450084230572,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 66,
#   'train_log': 4,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.8375182277621303,
#   'yad_class': '観光'},
#  {'yad_no': 67,
#   'train_log': 6,
#   'train_label': 5,
#   'test_log': 7,
#   'rate1': 0.8333333333333334,
#   'rate2': 1.9542091981116374,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 68,
#   'train_log': 10,
#   'train_label': 6,
#   'test_log': 6,
#   'rate1': 0.6,
#   'rate2': 1.0050218733145562,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 69,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 3,
#   'rate1': 0.75,
#   'rate2': 1.2562773416431954,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 70,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 3,
#   'rate1': 0.8,
#   'rate2': 1.0050218733145562,
#   'yad_class': '観光'},
#  {'yad_no': 71,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 4,
#   'rate1': 0.5,
#   'rate2': 1.6750364555242605,
#   'yad_class': '0'},
#  {'yad_no': 72,
#   'train_log': 13,
#   'train_label': 12,
#   'test_log': 8,
#   'rate1': 0.9230769230769231,
#   'rate2': 1.0307916649380064,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 73,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.3333333333333333,
#   'rate2': 1.116690970349507,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 74,
#   'train_log': 20,
#   'train_label': 14,
#   'test_log': 19,
#   'rate1': 0.7,
#   'rate2': 1.5912846327480474,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 75,
#   'train_log': 102,
#   'train_label': 56,
#   'test_log': 42,
#   'rate1': 0.5490196078431373,
#   'rate2': 0.689720893451166,
#   'yad_class': '観光'},
#  {'yad_no': 76,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 6,
#   'rate1': 1.0,
#   'rate2': 2.0100437466291123,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 77,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 1.0,
#   'rate2': 2.7917274258737677,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 78,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 79,
#   'train_log': 28,
#   'train_label': 11,
#   'test_log': 18,
#   'rate1': 0.39285714285714285,
#   'rate2': 1.0768091499798818,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 80,
#   'train_log': 42,
#   'train_label': 32,
#   'test_log': 13,
#   'rate1': 0.7619047619047619,
#   'rate2': 0.5184636648051283,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 81,
#   'train_log': 88,
#   'train_label': 73,
#   'test_log': 22,
#   'rate1': 0.8295454545454546,
#   'rate2': 0.4187591138810651,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 82,
#   'train_log': 157,
#   'train_label': 115,
#   'test_log': 33,
#   'rate1': 0.732484076433121,
#   'rate2': 0.352077726320386,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 83,
#   'train_log': 24,
#   'train_label': 23,
#   'test_log': 39,
#   'rate1': 0.9583333333333334,
#   'rate2': 2.7219342402269233,
#   'yad_class': '観光'},
#  {'yad_no': 84,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 85,
#   'train_log': 40,
#   'train_label': 39,
#   'test_log': 26,
#   'rate1': 0.975,
#   'rate2': 1.0887736960907695,
#   'yad_class': '観光'},
#  {'yad_no': 86,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 3,
#   'rate1': 1.3333333333333333,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 87,
#   'train_log': 4,
#   'train_label': 7,
#   'test_log': 41,
#   'rate1': 1.75,
#   'rate2': 17.16912366912367,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 88,
#   'train_log': 13,
#   'train_label': 4,
#   'test_log': 9,
#   'rate1': 0.3076923076923077,
#   'rate2': 1.1596406230552572,
#   'yad_class': '観光'},
#  {'yad_no': 89,
#   'train_log': 11,
#   'train_label': 10,
#   'test_log': 7,
#   'rate1': 0.9090909090909091,
#   'rate2': 1.0659322898790748,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 90,
#   'train_log': 18,
#   'train_label': 16,
#   'test_log': 20,
#   'rate1': 0.8888888888888888,
#   'rate2': 1.8611516172491784,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 91,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 92,
#   'train_log': 8,
#   'train_label': 10,
#   'test_log': 7,
#   'rate1': 1.25,
#   'rate2': 1.465656898583728,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 93,
#   'train_log': 6,
#   'train_label': 2,
#   'test_log': 6,
#   'rate1': 0.3333333333333333,
#   'rate2': 1.6750364555242605,
#   'yad_class': '0'},
#  {'yad_no': 94,
#   'train_log': 6,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 0.5583454851747535,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 95,
#   'train_log': 32,
#   'train_label': 27,
#   'test_log': 23,
#   'rate1': 0.84375,
#   'rate2': 1.2039324524080621,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 96,
#   'train_log': 40,
#   'train_label': 39,
#   'test_log': 114,
#   'rate1': 0.975,
#   'rate2': 4.773853898244143,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 97,
#   'train_log': 8,
#   'train_label': 7,
#   'test_log': 8,
#   'rate1': 0.875,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 98,
#   'train_log': 8,
#   'train_label': 4,
#   'test_log': 11,
#   'rate1': 0.5,
#   'rate2': 2.303175126345858,
#   'yad_class': '観光'},
#  {'yad_no': 99,
#   'train_log': 16,
#   'train_label': 21,
#   'test_log': 2,
#   'rate1': 1.3125,
#   'rate2': 0.20937955694053256,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 100,
#   'train_log': 18,
#   'train_label': 18,
#   'test_log': 16,
#   'rate1': 1.0,
#   'rate2': 1.4889212937993426,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 101,
#   'train_log': 206,
#   'train_label': 141,
#   'test_log': 48,
#   'rate1': 0.6844660194174758,
#   'rate2': 0.39029975662701216,
#   'yad_class': '観光'},
#  {'yad_no': 102,
#   'train_log': 18,
#   'train_label': 17,
#   'test_log': 25,
#   'rate1': 0.9444444444444444,
#   'rate2': 2.326439521561473,
#   'yad_class': '観光'},
#  {'yad_no': 103,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 6,
#   'rate1': 0.6666666666666666,
#   'rate2': 3.350072911048521,
#   'yad_class': '0'},
#  {'yad_no': 104,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303,
#   'yad_class': '0'},
#  {'yad_no': 105,
#   'train_log': 95,
#   'train_label': 80,
#   'test_log': 4,
#   'rate1': 0.8421052631578947,
#   'rate2': 0.07052785075891622,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 106,
#   'train_log': 25,
#   'train_label': 22,
#   'test_log': 21,
#   'rate1': 0.88,
#   'rate2': 1.4070306226403788,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 107,
#   'train_log': 26,
#   'train_label': 21,
#   'test_log': 27,
#   'rate1': 0.8076923076923077,
#   'rate2': 1.739460934582886,
#   'yad_class': '観光'},
#  {'yad_no': 108,
#   'train_log': 10,
#   'train_label': 6,
#   'test_log': 47,
#   'rate1': 0.6,
#   'rate2': 7.8726713409640245,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 109,
#   'train_log': 270,
#   'train_label': 215,
#   'test_log': 92,
#   'rate1': 0.7962962962962963,
#   'rate2': 0.5707531626230813,
#   'yad_class': '観光'},
#  {'yad_no': 110,
#   'train_log': 3,
#   'train_label': 5,
#   'test_log': 4,
#   'rate1': 1.6666666666666667,
#   'rate2': 2.233381940699014,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 111,
#   'train_log': 42,
#   'train_label': 43,
#   'test_log': 20,
#   'rate1': 1.0238095238095237,
#   'rate2': 0.797636407392505,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 112,
#   'train_log': 18,
#   'train_label': 22,
#   'test_log': 22,
#   'rate1': 1.2222222222222223,
#   'rate2': 2.0472667789740964,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 113,
#   'train_log': 4,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 1.25,
#   'rate2': 0.8375182277621303,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 114,
#   'train_log': 2,
#   'train_label': 6,
#   'test_log': 4,
#   'rate1': 3.0,
#   'rate2': 3.350072911048521,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 115,
#   'train_log': 71,
#   'train_label': 42,
#   'test_log': 34,
#   'rate1': 0.5915492957746479,
#   'rate2': 0.802130133631336,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 116,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.6700145822097042,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 117,
#   'train_log': 36,
#   'train_label': 25,
#   'test_log': 23,
#   'rate1': 0.6944444444444444,
#   'rate2': 1.0701621799182774,
#   'yad_class': '観光'},
#  {'yad_no': 118,
#   'train_log': 17,
#   'train_label': 10,
#   'test_log': 15,
#   'rate1': 0.5882352941176471,
#   'rate2': 1.4779733431096416,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 119,
#   'train_log': 93,
#   'train_label': 70,
#   'test_log': 46,
#   'rate1': 0.7526881720430108,
#   'rate2': 0.8285126554206019,
#   'yad_class': '観光'},
#  {'yad_no': 120,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 4,
#   'rate1': 1.0,
#   'rate2': 1.3400291644194084,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 121,
#   'train_log': 72,
#   'train_label': 67,
#   'test_log': 3,
#   'rate1': 0.9305555555555556,
#   'rate2': 0.06979318564684418,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 122,
#   'train_log': 27,
#   'train_label': 22,
#   'test_log': 3,
#   'rate1': 0.8148148148148148,
#   'rate2': 0.18611516172491782,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 123,
#   'train_log': 12,
#   'train_label': 3,
#   'test_log': 6,
#   'rate1': 0.25,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 124,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.3333333333333333,
#   'rate2': 1.116690970349507,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 125,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.6750364555242605,
#   'yad_class': '0'},
#  {'yad_no': 126,
#   'train_log': 16,
#   'train_label': 13,
#   'test_log': 9,
#   'rate1': 0.8125,
#   'rate2': 0.9422080062323965,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 127,
#   'train_log': 8,
#   'train_label': 4,
#   'test_log': 5,
#   'rate1': 0.5,
#   'rate2': 1.0468977847026628,
#   'yad_class': '観光'},
#  {'yad_no': 128,
#   'train_log': 24,
#   'train_label': 30,
#   'test_log': 10,
#   'rate1': 1.25,
#   'rate2': 0.6979318564684419,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 129,
#   'train_log': 8,
#   'train_label': 5,
#   'test_log': 4,
#   'rate1': 0.625,
#   'rate2': 0.8375182277621303,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 130,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 131,
#   'train_log': 15,
#   'train_label': 21,
#   'test_log': 11,
#   'rate1': 1.4,
#   'rate2': 1.2283600673844577,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 132,
#   'train_log': 20,
#   'train_label': 18,
#   'test_log': 15,
#   'rate1': 0.9,
#   'rate2': 1.2562773416431954,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 133,
#   'train_log': 6,
#   'train_label': 5,
#   'test_log': 3,
#   'rate1': 0.8333333333333334,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 134,
#   'train_log': 115,
#   'train_label': 79,
#   'test_log': 91,
#   'rate1': 0.6869565217391305,
#   'rate2': 1.3254636300235452,
#   'yad_class': '観光'},
#  {'yad_no': 135,
#   'train_log': 43,
#   'train_label': 38,
#   'test_log': 25,
#   'rate1': 0.8837209302325582,
#   'rate2': 0.9738584043745702,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 136,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 20,
#   'rate1': 1.0,
#   'rate2': 6.700145822097042,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 137,
#   'train_log': 39,
#   'train_label': 35,
#   'test_log': 32,
#   'rate1': 0.8974358974358975,
#   'rate2': 1.3743888865840086,
#   'yad_class': '観光'},
#  {'yad_no': 138,
#   'train_log': 21,
#   'train_label': 25,
#   'test_log': 29,
#   'rate1': 1.1904761904761905,
#   'rate2': 2.3131455814382647,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 139,
#   'train_log': 41,
#   'train_label': 30,
#   'test_log': 25,
#   'rate1': 0.7317073170731707,
#   'rate2': 1.0213636923928417,
#   'yad_class': '観光'},
#  {'yad_no': 140,
#   'train_log': 16,
#   'train_label': 17,
#   'test_log': 8,
#   'rate1': 1.0625,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 141,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303,
#   'yad_class': '0'},
#  {'yad_no': 142,
#   'train_log': 6,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.5583454851747535,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 143,
#   'train_log': 144,
#   'train_label': 68,
#   'test_log': 68,
#   'rate1': 0.4722222222222222,
#   'rate2': 0.7909894373309008,
#   'yad_class': '観光'},
#  {'yad_no': 144,
#   'train_log': 28,
#   'train_label': 17,
#   'test_log': 31,
#   'rate1': 0.6071428571428571,
#   'rate2': 1.8545046471875741,
#   'yad_class': '観光'},
#  {'yad_no': 145,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 7,
#   'rate1': 1.5,
#   'rate2': 5.862627594334912,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 146,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 7,
#   'rate1': 0.6666666666666666,
#   'rate2': 3.908418396223275,
#   'yad_class': '0'},
#  {'yad_no': 147,
#   'train_log': 4,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 148,
#   'train_log': 108,
#   'train_label': 64,
#   'test_log': 66,
#   'rate1': 0.5925925925925926,
#   'rate2': 1.0236333894870482,
#   'yad_class': '観光'},
#  {'yad_no': 149,
#   'train_log': 21,
#   'train_label': 21,
#   'test_log': 7,
#   'rate1': 1.0,
#   'rate2': 0.5583454851747535,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 150,
#   'train_log': 59,
#   'train_label': 59,
#   'test_log': 27,
#   'rate1': 1.0,
#   'rate2': 0.7665421067653395,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 151,
#   'train_log': 24,
#   'train_label': 18,
#   'test_log': 8,
#   'rate1': 0.75,
#   'rate2': 0.5583454851747535,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 152,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 153,
#   'train_log': 43,
#   'train_label': 19,
#   'test_log': 6,
#   'rate1': 0.4418604651162791,
#   'rate2': 0.23372601704989682,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 154,
#   'train_log': 22,
#   'train_label': 18,
#   'test_log': 10,
#   'rate1': 0.8181818181818182,
#   'rate2': 0.761380207056482,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 155,
#   'train_log': 18,
#   'train_label': 12,
#   'test_log': 11,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.0236333894870482,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 156,
#   'train_log': 3,
#   'train_label': 6,
#   'test_log': 6,
#   'rate1': 2.0,
#   'rate2': 3.350072911048521,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 157,
#   'train_log': 9,
#   'train_label': 11,
#   'test_log': 2,
#   'rate1': 1.2222222222222223,
#   'rate2': 0.37223032344983564,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 158,
#   'train_log': 20,
#   'train_label': 14,
#   'test_log': 9,
#   'rate1': 0.7,
#   'rate2': 0.7537664049859173,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 159,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 160,
#   'train_log': 28,
#   'train_label': 20,
#   'test_log': 8,
#   'rate1': 0.7142857142857143,
#   'rate2': 0.478581844435503,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 161,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303,
#   'yad_class': '0'},
#  {'yad_no': 162,
#   'train_log': 22,
#   'train_label': 11,
#   'test_log': 4,
#   'rate1': 0.5,
#   'rate2': 0.30455208282259283,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 163,
#   'train_log': 11,
#   'train_label': 7,
#   'test_log': 13,
#   'rate1': 0.6363636363636364,
#   'rate2': 1.9795885383468534,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 164,
#   'train_log': 11,
#   'train_label': 5,
#   'test_log': 10,
#   'rate1': 0.45454545454545453,
#   'rate2': 1.522760414112964,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 165,
#   'train_log': 6,
#   'train_label': 6,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.5583454851747535,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 166,
#   'train_log': 7,
#   'train_label': 8,
#   'test_log': 17,
#   'rate1': 1.1428571428571428,
#   'rate2': 4.0679456777017755,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 167,
#   'train_log': 5,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.6,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 168,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 169,
#   'train_log': 33,
#   'train_label': 22,
#   'test_log': 14,
#   'rate1': 0.6666666666666666,
#   'rate2': 0.7106215265860499,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 170,
#   'train_log': 131,
#   'train_label': 61,
#   'test_log': 42,
#   'rate1': 0.46564885496183206,
#   'rate2': 0.5370345887940376,
#   'yad_class': '観光'},
#  {'yad_no': 171,
#   'train_log': 76,
#   'train_label': 62,
#   'test_log': 7,
#   'rate1': 0.8157894736842105,
#   'rate2': 0.15427967353512925,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 172,
#   'train_log': 17,
#   'train_label': 12,
#   'test_log': 17,
#   'rate1': 0.7058823529411765,
#   'rate2': 1.6750364555242605,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 173,
#   'train_log': 11,
#   'train_label': 10,
#   'test_log': 2,
#   'rate1': 0.9090909090909091,
#   'rate2': 0.30455208282259283,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 174,
#   'train_log': 26,
#   'train_label': 18,
#   'test_log': 14,
#   'rate1': 0.6923076923076923,
#   'rate2': 0.9019427068207556,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 175,
#   'train_log': 30,
#   'train_label': 25,
#   'test_log': 20,
#   'rate1': 0.8333333333333334,
#   'rate2': 1.116690970349507,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 176,
#   'train_log': 45,
#   'train_label': 51,
#   'test_log': 6,
#   'rate1': 1.1333333333333333,
#   'rate2': 0.2233381940699014,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 177,
#   'train_log': 53,
#   'train_label': 19,
#   'test_log': 22,
#   'rate1': 0.3584905660377358,
#   'rate2': 0.6952981513496931,
#   'yad_class': '観光'},
#  {'yad_no': 178,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 179,
#   'train_log': 47,
#   'train_label': 32,
#   'test_log': 43,
#   'rate1': 0.6808510638297872,
#   'rate2': 1.5324801614370893,
#   'yad_class': '観光'},
#  {'yad_no': 180,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.8,
#   'rate2': 0.6700145822097042,
#   'yad_class': '観光'},
#  {'yad_no': 181,
#   'train_log': 6,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.8333333333333334,
#   'rate2': 0.5583454851747535,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 182,
#   'train_log': 13,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.38461538461538464,
#   'rate2': 0.2576979162345016,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 183,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.8,
#   'rate2': 0.6700145822097042,
#   'yad_class': '観光'},
#  {'yad_no': 184,
#   'train_log': 6,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.5583454851747535,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 185,
#   'train_log': 45,
#   'train_label': 49,
#   'test_log': 2,
#   'rate1': 1.0888888888888888,
#   'rate2': 0.07444606468996713,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 186,
#   'train_log': 37,
#   'train_label': 27,
#   'test_log': 5,
#   'rate1': 0.7297297297297297,
#   'rate2': 0.22635627777354872,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 187,
#   'train_log': 107,
#   'train_label': 61,
#   'test_log': 54,
#   'rate1': 0.5700934579439252,
#   'rate2': 0.8453455009187856,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 188,
#   'train_log': 5,
#   'train_label': 3,
#   'test_log': 3,
#   'rate1': 0.6,
#   'rate2': 1.0050218733145562,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 189,
#   'train_log': 19,
#   'train_label': 15,
#   'test_log': 10,
#   'rate1': 0.7894736842105263,
#   'rate2': 0.8815981344864529,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 190,
#   'train_log': 23,
#   'train_label': 18,
#   'test_log': 6,
#   'rate1': 0.782608695652174,
#   'rate2': 0.43696603187589406,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 191,
#   'train_log': 48,
#   'train_label': 48,
#   'test_log': 38,
#   'rate1': 1.0,
#   'rate2': 1.3260705272900395,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 192,
#   'train_log': 10,
#   'train_label': 8,
#   'test_log': 2,
#   'rate1': 0.8,
#   'rate2': 0.3350072911048521,
#   'yad_class': '観光'},
#  {'yad_no': 193,
#   'train_log': 79,
#   'train_label': 69,
#   'test_log': 82,
#   'rate1': 0.8734177215189873,
#   'rate2': 1.7386454348479665,
#   'yad_class': '観光'},
#  {'yad_no': 194,
#   'train_log': 9,
#   'train_label': 9,
#   'test_log': 6,
#   'rate1': 1.0,
#   'rate2': 1.116690970349507,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 195,
#   'train_log': 6,
#   'train_label': 6,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.5583454851747535,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 196,
#   'train_log': 43,
#   'train_label': 24,
#   'test_log': 23,
#   'rate1': 0.5581395348837209,
#   'rate2': 0.8959497320246044,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 197,
#   'train_log': 7,
#   'train_label': 3,
#   'test_log': 8,
#   'rate1': 0.42857142857142855,
#   'rate2': 1.914327377742012,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 198,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 6,
#   'rate1': 0.6666666666666666,
#   'rate2': 3.350072911048521,
#   'yad_class': '0'},
#  {'yad_no': 199,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.6750364555242605,
#   'yad_class': '0'},
#  {'yad_no': 200,
#   'train_log': 4,
#   'train_label': 4,
#   'test_log': 4,
#   'rate1': 1.0,
#   'rate2': 1.6750364555242605,
#   'yad_class': '観光'},
#  {'yad_no': 201,
#   'train_log': 7,
#   'train_label': 2,
#   'test_log': 31,
#   'rate1': 0.2857142857142857,
#   'rate2': 7.4180185887502965,
#   'yad_class': '0'},
#  {'yad_no': 202,
#   'train_log': 51,
#   'train_label': 40,
#   'test_log': 30,
#   'rate1': 0.7843137254901961,
#   'rate2': 0.9853155620730945,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 203,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 204,
#   'train_log': 13,
#   'train_label': 8,
#   'test_log': 9,
#   'rate1': 0.6153846153846154,
#   'rate2': 1.1596406230552572,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 205,
#   'train_log': 30,
#   'train_label': 29,
#   'test_log': 12,
#   'rate1': 0.9666666666666667,
#   'rate2': 0.6700145822097042,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 206,
#   'train_log': 29,
#   'train_label': 16,
#   'test_log': 20,
#   'rate1': 0.5517241379310345,
#   'rate2': 1.1551975555339729,
#   'yad_class': '観光'},
#  {'yad_no': 207,
#   'train_log': 2,
#   'train_label': 5,
#   'test_log': 5,
#   'rate1': 2.5,
#   'rate2': 4.187591138810651,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 208,
#   'train_log': 5,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.8,
#   'rate2': 0.6700145822097042,
#   'yad_class': '観光'},
#  {'yad_no': 209,
#   'train_log': 19,
#   'train_label': 2,
#   'test_log': 7,
#   'rate1': 0.10526315789473684,
#   'rate2': 0.617118694140517,
#   'yad_class': '0'},
#  {'yad_no': 210,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 7,
#   'rate1': 0.75,
#   'rate2': 2.931313797167456,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 211,
#   'train_log': 110,
#   'train_label': 76,
#   'test_log': 35,
#   'rate1': 0.6909090909090909,
#   'rate2': 0.5329661449395374,
#   'yad_class': '観光'},
#  {'yad_no': 212,
#   'train_log': 41,
#   'train_label': 38,
#   'test_log': 25,
#   'rate1': 0.926829268292683,
#   'rate2': 1.0213636923928417,
#   'yad_class': '観光'},
#  {'yad_no': 213,
#   'train_log': 52,
#   'train_label': 46,
#   'test_log': 46,
#   'rate1': 0.8846153846153846,
#   'rate2': 1.4817630183483843,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 214,
#   'train_log': 12,
#   'train_label': 9,
#   'test_log': 10,
#   'rate1': 0.75,
#   'rate2': 1.3958637129368838,
#   'yad_class': '観光'},
#  {'yad_no': 215,
#   'train_log': 28,
#   'train_label': 16,
#   'test_log': 20,
#   'rate1': 0.5714285714285714,
#   'rate2': 1.1964546110887575,
#   'yad_class': '観光'},
#  {'yad_no': 216,
#   'train_log': 4,
#   'train_label': 4,
#   'test_log': 7,
#   'rate1': 1.0,
#   'rate2': 2.931313797167456,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 217,
#   'train_log': 33,
#   'train_label': 18,
#   'test_log': 20,
#   'rate1': 0.5454545454545454,
#   'rate2': 1.0151736094086428,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 218,
#   'train_log': 9,
#   'train_label': 14,
#   'test_log': 2,
#   'rate1': 1.5555555555555556,
#   'rate2': 0.37223032344983564,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 219,
#   'train_log': 22,
#   'train_label': 22,
#   'test_log': 6,
#   'rate1': 1.0,
#   'rate2': 0.4568281242338892,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 220,
#   'train_log': 7,
#   'train_label': 2,
#   'test_log': 4,
#   'rate1': 0.2857142857142857,
#   'rate2': 0.957163688871006,
#   'yad_class': '0'},
#  {'yad_no': 221,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 222,
#   'train_log': 19,
#   'train_label': 22,
#   'test_log': 11,
#   'rate1': 1.1578947368421053,
#   'rate2': 0.9697579479350982,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 223,
#   'train_log': 13,
#   'train_label': 18,
#   'test_log': 43,
#   'rate1': 1.3846153846153846,
#   'rate2': 5.540505199041784,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 224,
#   'train_log': 207,
#   'train_label': 46,
#   'test_log': 9,
#   'rate1': 0.2222222222222222,
#   'rate2': 0.07282767197931567,
#   'yad_class': '観光'},
#  {'yad_no': 225,
#   'train_log': 28,
#   'train_label': 23,
#   'test_log': 18,
#   'rate1': 0.8214285714285714,
#   'rate2': 1.0768091499798818,
#   'yad_class': '観光'},
#  {'yad_no': 226,
#   'train_log': 16,
#   'train_label': 4,
#   'test_log': 11,
#   'rate1': 0.25,
#   'rate2': 1.151587563172929,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 227,
#   'train_log': 5,
#   'train_label': 6,
#   'test_log': 3,
#   'rate1': 1.2,
#   'rate2': 1.0050218733145562,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 228,
#   'train_log': 40,
#   'train_label': 39,
#   'test_log': 31,
#   'rate1': 0.975,
#   'rate2': 1.298153253031302,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 229,
#   'train_log': 20,
#   'train_label': 19,
#   'test_log': 28,
#   'rate1': 0.95,
#   'rate2': 2.3450510377339646,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 230,
#   'train_log': 20,
#   'train_label': 15,
#   'test_log': 5,
#   'rate1': 0.75,
#   'rate2': 0.4187591138810651,
#   'yad_class': '観光'},
#  {'yad_no': 231,
#   'train_log': 16,
#   'train_label': 21,
#   'test_log': 18,
#   'rate1': 1.3125,
#   'rate2': 1.884416012464793,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 232,
#   'train_log': 12,
#   'train_label': 6,
#   'test_log': 8,
#   'rate1': 0.5,
#   'rate2': 1.116690970349507,
#   'yad_class': '観光'},
#  {'yad_no': 233,
#   'train_log': 65,
#   'train_label': 30,
#   'test_log': 34,
#   'rate1': 0.46153846153846156,
#   'rate2': 0.8761729151973056,
#   'yad_class': '観光'},
#  {'yad_no': 234,
#   'train_log': 22,
#   'train_label': 17,
#   'test_log': 16,
#   'rate1': 0.7727272727272727,
#   'rate2': 1.2182083312903713,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 235,
#   'train_log': 9,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.3333333333333333,
#   'rate2': 0.37223032344983564,
#   'yad_class': '観光'},
#  {'yad_no': 236,
#   'train_log': 6,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 0.5583454851747535,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 237,
#   'train_log': 16,
#   'train_label': 16,
#   'test_log': 9,
#   'rate1': 1.0,
#   'rate2': 0.9422080062323965,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 238,
#   'train_log': 5,
#   'train_label': 3,
#   'test_log': 9,
#   'rate1': 0.6,
#   'rate2': 3.015065619943669,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 239,
#   'train_log': 19,
#   'train_label': 18,
#   'test_log': 2,
#   'rate1': 0.9473684210526315,
#   'rate2': 0.17631962689729058,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 240,
#   'train_log': 35,
#   'train_label': 26,
#   'test_log': 21,
#   'rate1': 0.7428571428571429,
#   'rate2': 1.0050218733145562,
#   'yad_class': '観光'},
#  {'yad_no': 241,
#   'train_log': 12,
#   'train_label': 9,
#   'test_log': 18,
#   'rate1': 0.75,
#   'rate2': 2.5125546832863908,
#   'yad_class': '観光'},
#  {'yad_no': 242,
#   'train_log': 8,
#   'train_label': 6,
#   'test_log': 5,
#   'rate1': 0.75,
#   'rate2': 1.0468977847026628,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 243,
#   'train_log': 71,
#   'train_label': 47,
#   'test_log': 45,
#   'rate1': 0.6619718309859155,
#   'rate2': 1.0616428239238271,
#   'yad_class': '観光'},
#  {'yad_no': 244,
#   'train_log': 56,
#   'train_label': 51,
#   'test_log': 59,
#   'rate1': 0.9107142857142857,
#   'rate2': 1.7647705513559173,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 245,
#   'train_log': 94,
#   'train_label': 100,
#   'test_log': 11,
#   'rate1': 1.0638297872340425,
#   'rate2': 0.19601490436986027,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 246,
#   'train_log': 55,
#   'train_label': 21,
#   'test_log': 34,
#   'rate1': 0.38181818181818183,
#   'rate2': 1.0354770815968155,
#   'yad_class': '観光'},
#  {'yad_no': 247,
#   'train_log': 6,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.5,
#   'rate2': 1.3958637129368838,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 248,
#   'train_log': 47,
#   'train_label': 37,
#   'test_log': 29,
#   'rate1': 0.7872340425531915,
#   'rate2': 1.0335331321319905,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 249,
#   'train_log': 17,
#   'train_label': 6,
#   'test_log': 11,
#   'rate1': 0.35294117647058826,
#   'rate2': 1.083847118280404,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 250,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 5,
#   'rate1': 1.3333333333333333,
#   'rate2': 2.7917274258737677,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 251,
#   'train_log': 51,
#   'train_label': 54,
#   'test_log': 3,
#   'rate1': 1.0588235294117647,
#   'rate2': 0.09853155620730944,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 252,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 253,
#   'train_log': 59,
#   'train_label': 44,
#   'test_log': 33,
#   'rate1': 0.7457627118644068,
#   'rate2': 0.9368847971576372,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 254,
#   'train_log': 68,
#   'train_label': 48,
#   'test_log': 2,
#   'rate1': 0.7058823529411765,
#   'rate2': 0.04926577810365472,
#   'yad_class': '観光'},
#  {'yad_no': 255,
#   'train_log': 132,
#   'train_label': 74,
#   'test_log': 75,
#   'rate1': 0.5606060606060606,
#   'rate2': 0.9517252588206027,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 256,
#   'train_log': 20,
#   'train_label': 16,
#   'test_log': 7,
#   'rate1': 0.8,
#   'rate2': 0.5862627594334912,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 257,
#   'train_log': 10,
#   'train_label': 9,
#   'test_log': 10,
#   'rate1': 0.9,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 258,
#   'train_log': 5,
#   'train_label': 3,
#   'test_log': 3,
#   'rate1': 0.6,
#   'rate2': 1.0050218733145562,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 259,
#   'train_log': 18,
#   'train_label': 10,
#   'test_log': 11,
#   'rate1': 0.5555555555555556,
#   'rate2': 1.0236333894870482,
#   'yad_class': '観光'},
#  {'yad_no': 260,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954,
#   'yad_class': '0'},
#  {'yad_no': 261,
#   'train_log': 8,
#   'train_label': 5,
#   'test_log': 3,
#   'rate1': 0.625,
#   'rate2': 0.6281386708215977,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 262,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 263,
#   'train_log': 28,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.17857142857142858,
#   'rate2': 0.11964546110887575,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 264,
#   'train_log': 14,
#   'train_label': 11,
#   'test_log': 8,
#   'rate1': 0.7857142857142857,
#   'rate2': 0.957163688871006,
#   'yad_class': '観光'},
#  {'yad_no': 265,
#   'train_log': 24,
#   'train_label': 17,
#   'test_log': 19,
#   'rate1': 0.7083333333333334,
#   'rate2': 1.3260705272900395,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 266,
#   'train_log': 28,
#   'train_label': 23,
#   'test_log': 24,
#   'rate1': 0.8214285714285714,
#   'rate2': 1.435745533306509,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 267,
#   'train_log': 77,
#   'train_label': 32,
#   'test_log': 86,
#   'rate1': 0.4155844155844156,
#   'rate2': 1.8708199373387844,
#   'yad_class': '観光'},
#  {'yad_no': 268,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.75,
#   'rate2': 0.8375182277621303,
#   'yad_class': '観光'},
#  {'yad_no': 269,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954,
#   'yad_class': '0'},
#  {'yad_no': 270,
#   'train_log': 7,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.2857142857142857,
#   'rate2': 0.478581844435503,
#   'yad_class': '0'},
#  {'yad_no': 271,
#   'train_log': 35,
#   'train_label': 19,
#   'test_log': 3,
#   'rate1': 0.5428571428571428,
#   'rate2': 0.1435745533306509,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 272,
#   'train_log': 9,
#   'train_label': 5,
#   'test_log': 6,
#   'rate1': 0.5555555555555556,
#   'rate2': 1.116690970349507,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 273,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 274,
#   'train_log': 2,
#   'train_label': 5,
#   'test_log': 3,
#   'rate1': 2.5,
#   'rate2': 2.5125546832863908,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 275,
#   'train_log': 82,
#   'train_label': 61,
#   'test_log': 33,
#   'rate1': 0.7439024390243902,
#   'rate2': 0.6741000369792756,
#   'yad_class': '観光'},
#  {'yad_no': 276,
#   'train_log': 109,
#   'train_label': 57,
#   'test_log': 67,
#   'rate1': 0.5229357798165137,
#   'rate2': 1.0296095644048207,
#   'yad_class': '観光'},
#  {'yad_no': 277,
#   'train_log': 101,
#   'train_label': 72,
#   'test_log': 41,
#   'rate1': 0.7128712871287128,
#   'rate2': 0.67996529382668,
#   'yad_class': '観光'},
#  {'yad_no': 278,
#   'train_log': 20,
#   'train_label': 17,
#   'test_log': 4,
#   'rate1': 0.85,
#   'rate2': 0.3350072911048521,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 279,
#   'train_log': 13,
#   'train_label': 14,
#   'test_log': 12,
#   'rate1': 1.0769230769230769,
#   'rate2': 1.5461874974070098,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 280,
#   'train_log': 18,
#   'train_label': 16,
#   'test_log': 13,
#   'rate1': 0.8888888888888888,
#   'rate2': 1.209748551211966,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 281,
#   'train_log': 57,
#   'train_label': 40,
#   'test_log': 41,
#   'rate1': 0.7017543859649122,
#   'rate2': 1.2048507837981524,
#   'yad_class': '観光'},
#  {'yad_no': 282,
#   'train_log': 30,
#   'train_label': 16,
#   'test_log': 17,
#   'rate1': 0.5333333333333333,
#   'rate2': 0.9491873247970809,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 283,
#   'train_log': 5,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.6700145822097042,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 284,
#   'train_log': 6,
#   'train_label': 8,
#   'test_log': 3,
#   'rate1': 1.3333333333333333,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 285,
#   'train_log': 38,
#   'train_label': 25,
#   'test_log': 16,
#   'rate1': 0.6578947368421053,
#   'rate2': 0.7052785075891623,
#   'yad_class': '観光'},
#  {'yad_no': 286,
#   'train_log': 21,
#   'train_label': 19,
#   'test_log': 7,
#   'rate1': 0.9047619047619048,
#   'rate2': 0.5583454851747535,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 287,
#   'train_log': 6,
#   'train_label': 6,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.5583454851747535,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 288,
#   'train_log': 67,
#   'train_label': 59,
#   'test_log': 30,
#   'rate1': 0.8805970149253731,
#   'rate2': 0.7500163233690719,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 289,
#   'train_log': 38,
#   'train_label': 31,
#   'test_log': 43,
#   'rate1': 0.8157894736842105,
#   'rate2': 1.8954359891458736,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 290,
#   'train_log': 31,
#   'train_label': 26,
#   'test_log': 6,
#   'rate1': 0.8387096774193549,
#   'rate2': 0.3242006042950182,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 291,
#   'train_log': 41,
#   'train_label': 40,
#   'test_log': 63,
#   'rate1': 0.975609756097561,
#   'rate2': 2.5738365048299614,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 292,
#   'train_log': 12,
#   'train_label': 3,
#   'test_log': 9,
#   'rate1': 0.25,
#   'rate2': 1.2562773416431954,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 293,
#   'train_log': 6,
#   'train_label': 2,
#   'test_log': 11,
#   'rate1': 0.3333333333333333,
#   'rate2': 3.070900168461144,
#   'yad_class': '0'},
#  {'yad_no': 294,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.75,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 295,
#   'train_log': 8,
#   'train_label': 4,
#   'test_log': 9,
#   'rate1': 0.5,
#   'rate2': 1.884416012464793,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 296,
#   'train_log': 28,
#   'train_label': 22,
#   'test_log': 41,
#   'rate1': 0.7857142857142857,
#   'rate2': 2.452731952731953,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 297,
#   'train_log': 38,
#   'train_label': 47,
#   'test_log': 5,
#   'rate1': 1.236842105263158,
#   'rate2': 0.22039953362161321,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 298,
#   'train_log': 16,
#   'train_label': 13,
#   'test_log': 18,
#   'rate1': 0.8125,
#   'rate2': 1.884416012464793,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 299,
#   'train_log': 31,
#   'train_label': 21,
#   'test_log': 27,
#   'rate1': 0.6774193548387096,
#   'rate2': 1.4589027193275816,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 300,
#   'train_log': 10,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.2,
#   'rate2': 0.3350072911048521,
#   'yad_class': '0'},
#  {'yad_no': 301,
#   'train_log': 41,
#   'train_label': 30,
#   'test_log': 48,
#   'rate1': 0.7317073170731707,
#   'rate2': 1.961018289394256,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 302,
#   'train_log': 12,
#   'train_label': 6,
#   'test_log': 6,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 303,
#   'train_log': 10,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.3350072911048521,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 304,
#   'train_log': 76,
#   'train_label': 45,
#   'test_log': 42,
#   'rate1': 0.5921052631578947,
#   'rate2': 0.9256780412107757,
#   'yad_class': '観光'},
#  {'yad_no': 305,
#   'train_log': 50,
#   'train_label': 21,
#   'test_log': 39,
#   'rate1': 0.42,
#   'rate2': 1.3065284353089233,
#   'yad_class': '観光'},
#  {'yad_no': 306,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 307,
#   'train_log': 296,
#   'train_label': 144,
#   'test_log': 160,
#   'rate1': 0.4864864864864865,
#   'rate2': 0.9054251110941949,
#   'yad_class': '観光'},
#  {'yad_no': 308,
#   'train_log': 22,
#   'train_label': 3,
#   'test_log': 4,
#   'rate1': 0.13636363636363635,
#   'rate2': 0.30455208282259283,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 309,
#   'train_log': 19,
#   'train_label': 7,
#   'test_log': 3,
#   'rate1': 0.3684210526315789,
#   'rate2': 0.26447944034593585,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 310,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.3333333333333333,
# ...
#   'rate2': 0.7882524496584755,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 897,
#   'train_log': 31,
#   'train_label': 22,
#   'test_log': 17,
#   'rate1': 0.7096774193548387,
#   'rate2': 0.9185683788358847,
#   'yad_class': '観光'},
#  {'yad_no': 898,
#   'train_log': 108,
#   'train_label': 73,
#   'test_log': 58,
#   'rate1': 0.6759259259259259,
#   'rate2': 0.8995566150037696,
#   'yad_class': '観光'},
#  {'yad_no': 899,
#   'train_log': 70,
#   'train_label': 33,
#   'test_log': 36,
#   'rate1': 0.4714285714285714,
#   'rate2': 0.8614473199839053,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 900,
#   'train_log': 13,
#   'train_label': 17,
#   'test_log': 3,
#   'rate1': 1.3076923076923077,
#   'rate2': 0.38654687435175245,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 901,
#   'train_log': 47,
#   'train_label': 40,
#   'test_log': 21,
#   'rate1': 0.851063829787234,
#   'rate2': 0.7484205439576482,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 902,
#   'train_log': 100,
#   'train_label': 57,
#   'test_log': 58,
#   'rate1': 0.57,
#   'rate2': 0.971521144204071,
#   'yad_class': '観光'},
#  {'yad_no': 903,
#   'train_log': 2,
#   'train_label': 8,
#   'test_log': 15,
#   'rate1': 4.0,
#   'rate2': 12.562773416431954,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 904,
#   'train_log': 25,
#   'train_label': 21,
#   'test_log': 3,
#   'rate1': 0.84,
#   'rate2': 0.20100437466291124,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 905,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 7,
#   'rate1': 1.5,
#   'rate2': 5.862627594334912,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 906,
#   'train_log': 79,
#   'train_label': 55,
#   'test_log': 42,
#   'rate1': 0.6962025316455697,
#   'rate2': 0.8905257105318852,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 907,
#   'train_log': 14,
#   'train_label': 9,
#   'test_log': 3,
#   'rate1': 0.6428571428571429,
#   'rate2': 0.35893638332662725,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 908,
#   'train_log': 21,
#   'train_label': 19,
#   'test_log': 18,
#   'rate1': 0.9047619047619048,
#   'rate2': 1.435745533306509,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 909,
#   'train_log': 46,
#   'train_label': 43,
#   'test_log': 8,
#   'rate1': 0.9347826086956522,
#   'rate2': 0.29131068791726267,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 910,
#   'train_log': 25,
#   'train_label': 35,
#   'test_log': 8,
#   'rate1': 1.4,
#   'rate2': 0.5360116657677634,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 911,
#   'train_log': 7,
#   'train_label': 2,
#   'test_log': 7,
#   'rate1': 0.2857142857142857,
#   'rate2': 1.6750364555242605,
#   'yad_class': '0'},
#  {'yad_no': 912,
#   'train_log': 50,
#   'train_label': 26,
#   'test_log': 50,
#   'rate1': 0.52,
#   'rate2': 1.6750364555242605,
#   'yad_class': '観光'},
#  {'yad_no': 913,
#   'train_log': 9,
#   'train_label': 5,
#   'test_log': 7,
#   'rate1': 0.5555555555555556,
#   'rate2': 1.3028061320744249,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 914,
#   'train_log': 54,
#   'train_label': 22,
#   'test_log': 2,
#   'rate1': 0.4074074074074074,
#   'rate2': 0.06203838724163927,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 915,
#   'train_log': 754,
#   'train_label': 244,
#   'test_log': 347,
#   'rate1': 0.32360742705570295,
#   'rate2': 0.7708722149428626,
#   'yad_class': '観光'},
#  {'yad_no': 916,
#   'train_log': 17,
#   'train_label': 14,
#   'test_log': 6,
#   'rate1': 0.8235294117647058,
#   'rate2': 0.5911893372438567,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 917,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': '0'},
#  {'yad_no': 918,
#   'train_log': 59,
#   'train_label': 33,
#   'test_log': 84,
#   'rate1': 0.559322033898305,
#   'rate2': 2.3847976654921674,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 919,
#   'train_log': 29,
#   'train_label': 28,
#   'test_log': 15,
#   'rate1': 0.9655172413793104,
#   'rate2': 0.8663981666504796,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 920,
#   'train_log': 6,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.3333333333333333,
#   'rate2': 0.5583454851747535,
#   'yad_class': '0'},
#  {'yad_no': 921,
#   'train_log': 190,
#   'train_label': 110,
#   'test_log': 49,
#   'rate1': 0.5789473684210527,
#   'rate2': 0.431983085898362,
#   'yad_class': '観光'},
#  {'yad_no': 922,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 3,
#   'rate1': 1.0,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 923,
#   'train_log': 6,
#   'train_label': 4,
#   'test_log': 4,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.116690970349507,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 924,
#   'train_log': 81,
#   'train_label': 63,
#   'test_log': 3,
#   'rate1': 0.7777777777777778,
#   'rate2': 0.06203838724163927,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 925,
#   'train_log': 61,
#   'train_label': 74,
#   'test_log': 34,
#   'rate1': 1.2131147540983607,
#   'rate2': 0.9336268768495878,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 926,
#   'train_log': 65,
#   'train_label': 30,
#   'test_log': 39,
#   'rate1': 0.46153846153846156,
#   'rate2': 1.0050218733145562,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 927,
#   'train_log': 9,
#   'train_label': 8,
#   'test_log': 17,
#   'rate1': 0.8888888888888888,
#   'rate2': 3.163957749323603,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 928,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 929,
#   'train_log': 17,
#   'train_label': 15,
#   'test_log': 6,
#   'rate1': 0.8823529411764706,
#   'rate2': 0.5911893372438567,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 930,
#   'train_log': 69,
#   'train_label': 23,
#   'test_log': 35,
#   'rate1': 0.3333333333333333,
#   'rate2': 0.8496561730920162,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 931,
#   'train_log': 67,
#   'train_label': 33,
#   'test_log': 49,
#   'rate1': 0.4925373134328358,
#   'rate2': 1.2250266615028174,
#   'yad_class': '観光'},
#  {'yad_no': 932,
#   'train_log': 12,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.25,
#   'rate2': 0.27917274258737673,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 933,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 934,
#   'train_log': 25,
#   'train_label': 13,
#   'test_log': 25,
#   'rate1': 0.52,
#   'rate2': 1.6750364555242605,
#   'yad_class': '観光'},
#  {'yad_no': 935,
#   'train_log': 78,
#   'train_label': 52,
#   'test_log': 65,
#   'rate1': 0.6666666666666666,
#   'rate2': 1.3958637129368838,
#   'yad_class': '観光'},
#  {'yad_no': 936,
#   'train_log': 6,
#   'train_label': 6,
#   'test_log': 7,
#   'rate1': 1.0,
#   'rate2': 1.9542091981116374,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 937,
#   'train_log': 15,
#   'train_label': 9,
#   'test_log': 19,
#   'rate1': 0.6,
#   'rate2': 2.121712843664063,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 938,
#   'train_log': 17,
#   'train_label': 10,
#   'test_log': 10,
#   'rate1': 0.5882352941176471,
#   'rate2': 0.9853155620730945,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 939,
#   'train_log': 18,
#   'train_label': 16,
#   'test_log': 13,
#   'rate1': 0.8888888888888888,
#   'rate2': 1.209748551211966,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 940,
#   'train_log': 4,
#   'train_label': 9,
#   'test_log': 5,
#   'rate1': 2.25,
#   'rate2': 2.0937955694053256,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 941,
#   'train_log': 73,
#   'train_label': 52,
#   'test_log': 61,
#   'rate1': 0.7123287671232876,
#   'rate2': 1.3996879970819163,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 942,
#   'train_log': 7,
#   'train_label': 6,
#   'test_log': 8,
#   'rate1': 0.8571428571428571,
#   'rate2': 1.914327377742012,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 943,
#   'train_log': 101,
#   'train_label': 66,
#   'test_log': 37,
#   'rate1': 0.6534653465346535,
#   'rate2': 0.6136272163801746,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 944,
#   'train_log': 4,
#   'train_label': 4,
#   'test_log': 17,
#   'rate1': 1.0,
#   'rate2': 7.118904935978107,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 945,
#   'train_log': 80,
#   'train_label': 53,
#   'test_log': 49,
#   'rate1': 0.6625,
#   'rate2': 1.0259598290086096,
#   'yad_class': '観光'},
#  {'yad_no': 946,
#   'train_log': 11,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.18181818181818182,
#   'rate2': 0.4568281242338892,
#   'yad_class': '0'},
#  {'yad_no': 947,
#   'train_log': 2,
#   'train_label': 4,
#   'test_log': 14,
#   'rate1': 2.0,
#   'rate2': 11.725255188669824,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 948,
#   'train_log': 4,
#   'train_label': 7,
#   'test_log': 2,
#   'rate1': 1.75,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 949,
#   'train_log': 22,
#   'train_label': 13,
#   'test_log': 12,
#   'rate1': 0.5909090909090909,
#   'rate2': 0.9136562484677784,
#   'yad_class': '観光'},
#  {'yad_no': 950,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 22,
#   'rate1': 1.0,
#   'rate2': 12.283600673844576,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 951,
#   'train_log': 57,
#   'train_label': 51,
#   'test_log': 21,
#   'rate1': 0.8947368421052632,
#   'rate2': 0.617118694140517,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 952,
#   'train_log': 45,
#   'train_label': 44,
#   'test_log': 52,
#   'rate1': 0.9777777777777777,
#   'rate2': 1.9355976819391454,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 953,
#   'train_log': 2,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 2.0,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 954,
#   'train_log': 66,
#   'train_label': 68,
#   'test_log': 38,
#   'rate1': 1.0303030303030303,
#   'rate2': 0.9644149289382107,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 955,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 7,
#   'rate1': 1.5,
#   'rate2': 5.862627594334912,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 956,
#   'train_log': 6,
#   'train_label': 3,
#   'test_log': 5,
#   'rate1': 0.5,
#   'rate2': 1.3958637129368838,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 957,
#   'train_log': 79,
#   'train_label': 62,
#   'test_log': 48,
#   'rate1': 0.7848101265822784,
#   'rate2': 1.0177436691792976,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 958,
#   'train_log': 8,
#   'train_label': 5,
#   'test_log': 16,
#   'rate1': 0.625,
#   'rate2': 3.350072911048521,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 959,
#   'train_log': 29,
#   'train_label': 12,
#   'test_log': 17,
#   'rate1': 0.41379310344827586,
#   'rate2': 0.9819179222038767,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 960,
#   'train_log': 26,
#   'train_label': 32,
#   'test_log': 3,
#   'rate1': 1.2307692307692308,
#   'rate2': 0.19327343717587622,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 961,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.75,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 962,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 3,
#   'rate1': 0.5,
#   'rate2': 1.2562773416431954,
#   'yad_class': '0'},
#  {'yad_no': 963,
#   'train_log': 24,
#   'train_label': 18,
#   'test_log': 20,
#   'rate1': 0.75,
#   'rate2': 1.3958637129368838,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 964,
#   'train_log': 39,
#   'train_label': 36,
#   'test_log': 11,
#   'rate1': 0.9230769230769231,
#   'rate2': 0.472446179763253,
#   'yad_class': '観光'},
#  {'yad_no': 965,
#   'train_log': 19,
#   'train_label': 15,
#   'test_log': 16,
#   'rate1': 0.7894736842105263,
#   'rate2': 1.4105570151783247,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 966,
#   'train_log': 65,
#   'train_label': 34,
#   'test_log': 59,
#   'rate1': 0.5230769230769231,
#   'rate2': 1.5204177057835595,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 967,
#   'train_log': 3,
#   'train_label': 4,
#   'test_log': 2,
#   'rate1': 1.3333333333333333,
#   'rate2': 1.116690970349507,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 968,
#   'train_log': 37,
#   'train_label': 26,
#   'test_log': 19,
#   'rate1': 0.7027027027027027,
#   'rate2': 0.8601538555394851,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 969,
#   'train_log': 68,
#   'train_label': 60,
#   'test_log': 62,
#   'rate1': 0.8823529411764706,
#   'rate2': 1.5272391212132963,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 970,
#   'train_log': 2,
#   'train_label': 6,
#   'test_log': 9,
#   'rate1': 3.0,
#   'rate2': 7.537664049859172,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 971,
#   'train_log': 46,
#   'train_label': 35,
#   'test_log': 33,
#   'rate1': 0.7608695652173914,
#   'rate2': 1.2016565876587086,
#   'yad_class': '観光'},
#  {'yad_no': 972,
#   'train_log': 11,
#   'train_label': 7,
#   'test_log': 12,
#   'rate1': 0.6363636363636364,
#   'rate2': 1.8273124969355568,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 973,
#   'train_log': 29,
#   'train_label': 18,
#   'test_log': 23,
#   'rate1': 0.6206896551724138,
#   'rate2': 1.3284771888640687,
#   'yad_class': '観光'},
#  {'yad_no': 974,
#   'train_log': 10,
#   'train_label': 10,
#   'test_log': 16,
#   'rate1': 1.0,
#   'rate2': 2.680058328838817,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 975,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 976,
#   'train_log': 18,
#   'train_label': 19,
#   'test_log': 9,
#   'rate1': 1.0555555555555556,
#   'rate2': 0.8375182277621303,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 977,
#   'train_log': 8,
#   'train_label': 7,
#   'test_log': 33,
#   'rate1': 0.875,
#   'rate2': 6.909525379037575,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 978,
#   'train_log': 13,
#   'train_label': 5,
#   'test_log': 2,
#   'rate1': 0.38461538461538464,
#   'rate2': 0.2576979162345016,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 979,
#   'train_log': 28,
#   'train_label': 19,
#   'test_log': 13,
#   'rate1': 0.6785714285714286,
#   'rate2': 0.7776954972076924,
#   'yad_class': '観光'},
#  {'yad_no': 980,
#   'train_log': 21,
#   'train_label': 17,
#   'test_log': 41,
#   'rate1': 0.8095238095238095,
#   'rate2': 3.27030927030927,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 981,
#   'train_log': 24,
#   'train_label': 17,
#   'test_log': 23,
#   'rate1': 0.7083333333333334,
#   'rate2': 1.6052432698774164,
#   'yad_class': '観光'},
#  {'yad_no': 982,
#   'train_log': 18,
#   'train_label': 15,
#   'test_log': 12,
#   'rate1': 0.8333333333333334,
#   'rate2': 1.116690970349507,
#   'yad_class': '観光'},
#  {'yad_no': 983,
#   'train_log': 4,
#   'train_label': 3,
#   'test_log': 10,
#   'rate1': 0.75,
#   'rate2': 4.187591138810651,
#   'yad_class': '観光'},
#  {'yad_no': 984,
#   'train_log': 7,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 0.42857142857142855,
#   'rate2': 0.478581844435503,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 985,
#   'train_log': 9,
#   'train_label': 7,
#   'test_log': 11,
#   'rate1': 0.7777777777777778,
#   'rate2': 2.0472667789740964,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 986,
#   'train_log': 3,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 1.116690970349507,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 987,
#   'train_log': 14,
#   'train_label': 9,
#   'test_log': 4,
#   'rate1': 0.6428571428571429,
#   'rate2': 0.478581844435503,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 988,
#   'train_log': 8,
#   'train_label': 4,
#   'test_log': 5,
#   'rate1': 0.5,
#   'rate2': 1.0468977847026628,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 989,
#   'train_log': 55,
#   'train_label': 48,
#   'test_log': 40,
#   'rate1': 0.8727272727272727,
#   'rate2': 1.2182083312903713,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 990,
#   'train_log': 62,
#   'train_label': 38,
#   'test_log': 35,
#   'rate1': 0.6129032258064516,
#   'rate2': 0.9455850958604697,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 991,
#   'train_log': 7,
#   'train_label': 7,
#   'test_log': 2,
#   'rate1': 1.0,
#   'rate2': 0.478581844435503,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 992,
#   'train_log': 11,
#   'train_label': 6,
#   'test_log': 2,
#   'rate1': 0.5454545454545454,
#   'rate2': 0.30455208282259283,
#   'yad_class': 'ビジネスミドル'},
#  {'yad_no': 993,
#   'train_log': 4,
#   'train_label': 2,
#   'test_log': 2,
#   'rate1': 0.5,
#   'rate2': 0.8375182277621303,
#   'yad_class': '0'},
#  {'yad_no': 994,
#   'train_log': 16,
#   'train_label': 14,
#   'test_log': 17,
#   'rate1': 0.875,
#   'rate2': 1.7797262339945268,
#   'yad_class': '観光'},
#  {'yad_no': 995,
#   'train_log': 7,
#   'train_label': 5,
#   'test_log': 5,
#   'rate1': 0.7142857142857143,
#   'rate2': 1.1964546110887575,
#   'yad_class': '観光'},
#  {'yad_no': 996,
#   'train_log': 38,
#   'train_label': 26,
#   'test_log': 47,
#   'rate1': 0.6842105263157895,
#   'rate2': 2.0717556160431645,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 997,
#   'train_log': 39,
#   'train_label': 35,
#   'test_log': 38,
#   'rate1': 0.8974358974358975,
#   'rate2': 1.6320868028185103,
#   'yad_class': '観光ミドル'},
#  {'yad_no': 998,
#   'train_log': 2,
#   'train_label': 3,
#   'test_log': 2,
#   'rate1': 1.5,
#   'rate2': 1.6750364555242605,
#   'yad_class': 'ビジネス'},
#  {'yad_no': 999,
#   'train_log': 3,
#   'train_label': 2,
#   'test_log': 4,
#   'rate1': 0.6666666666666666,
#   'rate2': 2.233381940699014,
#   'yad_class': '0'},
#  ...]

# %% [markdown]
# # Code

# %%
from collections import defaultdict
from heapq import heappush, heappop

# %% [markdown]
# ### D[v][r] の計算

# %%
# データの加工

# train_logで実際に予約した宿をひけるようにしておく
map_reserved = defaultdict(int)
for idx, rec in train_label.iterrows():
  session_id, yad_no_reserved = rec
  map_reserved[session_id] = yad_no_reserved

# 縦持ちのセッションログを、session_id : [閲覧したyad_noのリスト] のdictに変換
def Make_session_list(session_log):
  map_session_yads = defaultdict(list)
  for _, row in session_log.iterrows():
    session_id = row[0]
    yad_no = row[2]
    map_session_yads[session_id].append(yad_no)
  return map_session_yads

map_session_yads_train = Make_session_list(train_log)
map_session_yads_test = Make_session_list(test_log)

# D[v][r]:= 「最後に宿vを閲覧して、宿rを予約した」セッションの件数 <- 重み付けを行う！
D = defaultdict(lambda:defaultdict(float))
for session_id, viewed_yad_no in map_session_yads_train.items():
  last_viewed = viewed_yad_no[-1]
  reserved = map_reserved[session_id]
  D[last_viewed][reserved] += each_counts[reserved]['rate2'] ** POW2

# D2[v][r] := sessionlength >= 2 に対して最後から二番目に見た宿と予約確率
D2 = defaultdict(lambda:defaultdict(float))
for session_id, viewed_yad_no in map_session_yads_train.items():
  if len(viewed_yad_no) == 1:
    continue
  last_viewed2 = viewed_yad_no[-2]
  reserved = map_reserved[session_id]
  if last_viewed2 == reserved:
    continue
  D2[last_viewed2][reserved] += each_counts[reserved]['rate2'] ** POW2
# Out:
# /var/folders/6k/nrp954t51fq50vv_ch4k2wc00000gn/T/ipykernel_649/3506799222.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   session_id = row[0]
# /var/folders/6k/nrp954t51fq50vv_ch4k2wc00000gn/T/ipykernel_649/3506799222.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   yad_no = row[2]

# %% [markdown]
# ### 各エリアでの人気な宿TOP10列挙

# %% [markdown]
# `test01.ipynb` では train_log における人気度を用いたが、これよりも test_log における人気度を用いた方が良いと思われる。
# しかし、「閲覧されるものの予約されにくいもの」というものもある可能性があるため、ここでは重み付けに rate1 を利用する。

# %%
yado_cnt = [0 for _ in range(15000)]

for idx, row in test_log.iterrows():
    yad_no = row[2]
    yado_cnt[yad_no] += each_counts[yad_no]['rate1'] ** POW1

sml_to_yado = {
    sml_cd: []
    for sml_cd in yado["sml_cd"]
}
yado_to_sml = {
    row[0]: row[12]
    for _, row in yado.iterrows()
}
for idx, row in yado.iterrows():
    yad_no = row[0]
    sml_cd = row[12]
    sml_to_yado[sml_cd].append(yad_no)
# Out:
# /var/folders/6k/nrp954t51fq50vv_ch4k2wc00000gn/T/ipykernel_649/2877134683.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   yad_no = row[2]
# /var/folders/6k/nrp954t51fq50vv_ch4k2wc00000gn/T/ipykernel_649/2877134683.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row[0]: row[12]
# /var/folders/6k/nrp954t51fq50vv_ch4k2wc00000gn/T/ipykernel_649/2877134683.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   yad_no = row[0]
# /var/folders/6k/nrp954t51fq50vv_ch4k2wc00000gn/T/ipykernel_649/2877134683.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sml_cd = row[12]

# %%
for sml_cd in sml_to_yado.keys():
    sml_to_yado[sml_cd] = sorted(sml_to_yado[sml_cd], key=lambda x: yado_cnt[x], reverse=True)[:50]

# %%
lrg_to_yado = {
    lrg_cd: []
    for lrg_cd in yado["lrg_cd"]
}
yado_to_lrg = {
    row[0]: row[11]
    for _, row in yado.iterrows()
}
for idx, row in yado.iterrows():
    yad_no = row[0]
    lrg_cd = row[11]
    lrg_to_yado[lrg_cd].append(yad_no)

for lrg_cd in lrg_to_yado.keys():
    lrg_to_yado[lrg_cd] = sorted(lrg_to_yado[lrg_cd], key=lambda x: yado_cnt[x], reverse=True)[:20]
# Out:
# /var/folders/6k/nrp954t51fq50vv_ch4k2wc00000gn/T/ipykernel_649/2705970059.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row[0]: row[11]
# /var/folders/6k/nrp954t51fq50vv_ch4k2wc00000gn/T/ipykernel_649/2705970059.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   yad_no = row[0]
# /var/folders/6k/nrp954t51fq50vv_ch4k2wc00000gn/T/ipykernel_649/2705970059.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lrg_cd = row[11]

# %%
popular_yados = [
    719, 2201, 13468, 12350, 2797
]

# %% [markdown]
# ### ビジネス-観光の分類を入れる

# %%
def sort_yado_with_type(search_yad_class, yad_no):
    yad_class = each_counts[yad_no]['yad_class']
    if yad_class == search_yad_class:
        return yado_cnt[yad_no]
    elif yad_class == "ビジネス" and search_yad_class == "ビジネスミドル":
        return yado_cnt[yad_no] * DECREASE_RATE
    elif yad_class == "観光" and search_yad_class == "観光ミドル":
        return yado_cnt[yad_no] * DECREASE_RATE
    elif yad_class == "ビジネスミドル" or yad_class == "観光ミドル":
        return yado_cnt[yad_no] * DECREASE_RATE
    else:
        return yado_cnt[yad_no] * DECREASE_RATE2

# %% [markdown]
# ### sml_cd での遷移関係

# %%
# 各sml_cdについて、最後に見た回数を数える
last_viewed_count_sml = {
    row[12]: 0
    for _, row in yado.iterrows()
}
for _, viewed_yad_no in map_session_yads_train.items():
    last_viewed = viewed_yad_no[-1]
    last_sml_cd = yado_to_sml[last_viewed]
    last_viewed_count_sml[last_sml_cd] += 1

# E[a][b] -> sml_cd='a' から sml_cd='b'に移動した回数
E = defaultdict(lambda:defaultdict(float))
for session_id, viewed_yad_no in map_session_yads_train.items():
    last_viewed = viewed_yad_no[-1]
    last_sml_cd = yado_to_sml[last_viewed]
    reserved = map_reserved[session_id]
    reserved_sml_cd = yado_to_sml[reserved]
    E[last_sml_cd][reserved_sml_cd] += 1 / last_viewed_count_sml[last_sml_cd]

# -> E[a][b] が欲しい確率！
# Out:
# /var/folders/6k/nrp954t51fq50vv_ch4k2wc00000gn/T/ipykernel_649/1805337463.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row[12]: 0

# %%
E
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'4044dac1931ddaa5a967e09506d76343': defaultdict(float,
#                          {'4044dac1931ddaa5a967e09506d76343': 0.9385113268608487,
#                           'af003d74af66f40a2511d2468db15fe0': 0.003236245954692557,
#                           '284ab43612caf399fb30093363f92a52': 0.029126213592233025,
#                           '20ad8785a30f125bee5a8a325782ab06': 0.004854368932038835,
#                           '8a3f01bdf9eb39e9ce6f4780590a51cd': 0.0016181229773462784,
#                           '33bfe292401fc7f99b8b9831a71f61ee': 0.003236245954692557,
#                           'e2f51242791849e72240784844876b89': 0.004854368932038835,
#                           'bb5a43cfd329c8cc725a8abf2651f537': 0.008090614886731393,
#                           '199073cb3739d73a10d0d96f0b4f8555': 0.003236245954692557,
#                           'ba9e619c37ec3475db6b5e1c3426289c': 0.0016181229773462784,
#                           '90a34785b0654fabbea6c52d74718e20': 0.0016181229773462784}),
#                           '2a8ec22a10c934258347f2bb4c23f5cf': 0.043478260869565216,
#                           'c6744b92de9176b526c7169ff7cbc71a': 0.043478260869565216}),
#              '0d4a02b3800088664b82825921c29ac4': defaultdict(float,
#                          {'0d4a02b3800088664b82825921c29ac4': 0.9500000000000003,
#                           'a730990582124b6ffa374dc90d0c4494': 0.05}),
#              '8710955f5b6edb0d6f82376b12133b30': defaultdict(float,
#                          {'8710955f5b6edb0d6f82376b12133b30': 0.9999999999999996}),
#              'e232a62762e334cfb9723577de045431': defaultdict(float,
#                          {'e232a62762e334cfb9723577de045431': 0.777777777777778,
#                           '6b2f1db7e5052fcdc401645b36f7109d': 0.16666666666666666,
#                           '1ff395b8e51454d0de1e0497700a2145': 0.05555555555555555}),
#              '08a0f7f92e29232d1d3bef9e0038c615': defaultdict(float,
#                          {'6b28dd1b948c50fffcde7f86e5c7d9cb': 0.4285714285714285,
#                           '08a0f7f92e29232d1d3bef9e0038c615': 0.5714285714285713}),
#              'f1ae5f1a101b24f381ddb19644bb9e2c': defaultdict(float,
#                          {'f1ae5f1a101b24f381ddb19644bb9e2c': 0.9999999999999999}),
#              '4b87fa0613d446ddf14a870793a328e1': defaultdict(float,
#                          {'9d9e1d08bd15f1303bb05f07ae9a4853': 0.16666666666666666,
#                           'eef688aa568fe0b6ae90da12f91c8827': 0.3333333333333333,
#                           '6c16395d3ba651be7f9dfc8f4b8b9ce4': 0.08333333333333333,
#                           '4b87fa0613d446ddf14a870793a328e1': 0.41666666666666663}),
#              '8c9e3f10c6abdc8b526c27d5fdfe22ed': defaultdict(float,
#                          {'8c9e3f10c6abdc8b526c27d5fdfe22ed': 0.4545454545454546,
#                           '83e662f358c404631d16491411868fa1': 0.18181818181818182,
#                           '74376dd9f0b2bb1c2e32e10ba05f858c': 0.18181818181818182,
#                           '5185dcadf66894f564cff41a3d66a444': 0.18181818181818182})})

# %% [markdown]
# ### 解答作成！

# %%
Predict = [ [0] * 10 for _ in range(len(test_session))]

def prod_weight(prod):
    return prod ** PROD_WEIGHT

def business_weight(yad, last_viewed):
    return 1.0

# session長さ1の時のDからの選び方
def get_for_single_session(idx, last_viewed, rank):
    sorted_yad_list = []
    for yad_no, viewed_cnt in D[last_viewed].items():
        heappush(sorted_yad_list, (-viewed_cnt * business_weight(yad_no, last_viewed), yad_no))
    
    while rank < 10 and sorted_yad_list:
        _, predicted_yad_no = heappop(sorted_yad_list)
        if predicted_yad_no in Predict[idx]:
            continue
        Predict[idx][rank] = predicted_yad_no
        rank += 1
    
    return rank

# session長さ2の時のDからの選び方
def get_for_twice_session(idx, last_viewed, last_viewed2, rank):
    # last_viewed, last_viewed2 を用いる
    yad_score = {}
    for yad_no, viewed_cnt in D[last_viewed].items():
        yad_score[yad_no] = viewed_cnt
    for yad_no, viewed_cnt in D[last_viewed2].items():
        if yad_no in yad_score:
            yad_score[yad_no] += viewed_cnt * SECOND_WEIGHT
        else:
            yad_score[yad_no] = viewed_cnt * SECOND_WEIGHT
    for yad_no, viewed_cnt in D2[last_viewed2].items():
        if yad_no in yad_score:
            yad_score[yad_no] += viewed_cnt * D2_WEIGHT
        else:
            yad_score[yad_no] = viewed_cnt * D2_WEIGHT
    
    sorted_yad_list = []
    for yad_no, viewed_cnt in yad_score.items():
        heappush(sorted_yad_list, (-viewed_cnt, yad_no))
    
    while rank < 10 and sorted_yad_list:
        _, predicted_yad_no = heappop(sorted_yad_list)
        if predicted_yad_no in Predict[idx]:
            continue
        Predict[idx][rank] = predicted_yad_no
        rank += 1
    
    return rank

# session長さ3以上の時のDからの選び方
def get_for_multiple_session(idx, last_viewed, last_viewed2, last_viewed3, rank):
    # last_viewed, last_viewed2 を用いる
    yad_score = {}
    for yad_no, viewed_cnt in D[last_viewed].items():
        yad_score[yad_no] = viewed_cnt
    for yad_no, viewed_cnt in D[last_viewed2].items():
        if yad_no in yad_score:
            yad_score[yad_no] += viewed_cnt * SECOND_WEIGHT
        else:
            yad_score[yad_no] = viewed_cnt * SECOND_WEIGHT
    for yad_no, viewed_cnt in D2[last_viewed2].items():
        if yad_no in yad_score:
            yad_score[yad_no] += viewed_cnt * D2_WEIGHT
        else:
            yad_score[yad_no] = viewed_cnt * D2_WEIGHT
    for yad_no, viewed_cnt in D[last_viewed3].items():
        if yad_no in yad_score:
            yad_score[yad_no] += viewed_cnt * SECOND_WEIGHT
        else:
            yad_score[yad_no] = viewed_cnt * SECOND_WEIGHT
    
    sorted_yad_list = []
    for yad_no, viewed_cnt in yad_score.items():
        heappush(sorted_yad_list, (-viewed_cnt, yad_no))
    
    while rank < 10 and sorted_yad_list:
        _, predicted_yad_no = heappop(sorted_yad_list)
        if predicted_yad_no in Predict[idx]:
            continue
        Predict[idx][rank] = predicted_yad_no
        rank += 1
    
    return rank


# session長さ1の時のEからのエリア選択
# 上位3件取ってきて、そのままEの値で重み付けを行う
def get_from_sml_single(idx, last_viewed, rank):
    viewed_sml_cd = yado_to_sml[last_viewed]
    score = {}
    sorted_sml_list = []
    for sml_cd, viewed_prod in E[viewed_sml_cd].items():
        heappush(sorted_sml_list, (-viewed_prod, sml_cd))
    
    cnt = 0
    while cnt < 3 and sorted_sml_list:
        prod, sml_cd = heappop(sorted_sml_list)
        prod = -prod
        # sml_cd の人気宿を prod で重み付け
        num = 0
        yad_list = sml_to_yado[sml_cd]
        while num < min(len(yad_list), 10):
            yad_no = yad_list[num]
            score[yad_no] = yado_cnt[yad_no] * prod_weight(prod)
            num += 1
        cnt += 1
    
    sorted_yad_list = []
    for yad_no, prod in score.items():
        heappush(sorted_yad_list, (-prod * business_weight(yad_no, last_viewed), yad_no))
    
    while rank < 10 and sorted_yad_list:
        _, predicted_yad_no = heappop(sorted_yad_list)
        if predicted_yad_no in Predict[idx]:
            continue
        Predict[idx][rank] = predicted_yad_no
        rank += 1
    
    return rank

# session長さ2以上の時のEからのエリア選択
# 上位3件取ってきて、そのままEの値で重み付けを行う
def get_from_sml_multiple(idx, last_viewed, last_viewed2, rank):
    viewed_sml_cd, viewed_sml_cd2 = yado_to_sml[last_viewed], yado_to_sml[last_viewed2]
    sml_score = {}
    for sml_cd, viewed_prod in E[viewed_sml_cd].items():
        sml_score[sml_cd] = viewed_prod
    for sml_cd, viewed_prod in E[viewed_sml_cd2].items():
        if sml_cd in sml_score:
            sml_score[sml_cd] += prod_weight(viewed_prod * SECOND_WEIGHT2)
        else:
            sml_score[sml_cd] = prod_weight(viewed_prod * SECOND_WEIGHT2)

    sorted_sml_list = []
    for sml_cd, prod in sml_score.items():
        heappush(sorted_sml_list, (-prod, sml_cd))
    
    score = {}
    cnt = 0
    while cnt < 3 and sorted_sml_list:
        prod, sml_cd = heappop(sorted_sml_list)
        prod = -prod
        # sml_cd の人気宿を prod で重み付け
        num = 0
        yad_list = sml_to_yado[sml_cd]
        while num < min(len(yad_list), 10):
            yad_no = yad_list[num]
            score[yad_no] = yado_cnt[yad_no] * prod_weight(prod)
            num += 1
        cnt += 1
    
    sorted_yad_list = []
    for yad_no, prod in score.items():
        heappush(sorted_yad_list, (-prod, yad_no))
    
    while rank < 10 and sorted_yad_list:
        _, predicted_yad_no = heappop(sorted_yad_list)
        if predicted_yad_no in Predict[idx]:
            continue
        Predict[idx][rank] = predicted_yad_no
        rank += 1
    
    return rank

"""メイン処理"""
not_enough = 0
for idx, session_id in enumerate(test_session["session_id"]):
    viewed_list = map_session_yads_test[session_id]
    last_viewed = viewed_list[-1]
    rank = 0
    
    cand, seen = [], set()
    for item in viewed_list:
        if item != last_viewed and item not in seen:
            cand.append(item)
            seen.add(item)
    
    for item in cand:
        Predict[idx][rank] = item
        rank += 1

    if len(viewed_list) == 1:
        rank = get_for_single_session(idx, last_viewed, rank)
        rank = get_from_sml_single(idx, last_viewed, rank)
    elif len(viewed_list) == 2:
        rank = get_for_twice_session(idx, last_viewed, viewed_list[-2], rank)
        rank = get_from_sml_multiple(idx, last_viewed, viewed_list[-2], rank)
    else:
        rank = get_for_multiple_session(idx, last_viewed, viewed_list[-2], viewed_list[-3], rank)
        rank = get_from_sml_multiple(idx, last_viewed, viewed_list[-2], rank)

    
    if rank == 10:
        continue

    not_enough += 10 - rank

    # それでも余っているならlrg_cdでの人気宿で埋める（考察余地あり）
    cnt = 0
    lrg_cd = yado_to_lrg[last_viewed]
    top_yados = lrg_to_yado[lrg_cd]
    last_class = each_counts[last_viewed]['yad_class']
    top_yados = sorted(top_yados, key=lambda x: sort_yado_with_type(last_class, x), reverse=True)
    while rank < 10 and cnt < len(top_yados):
        if top_yados[cnt] in Predict[idx]:
            cnt += 1
            continue
        Predict[idx][rank] = top_yados[cnt]
        cnt += 1
        rank += 1
    
    # それでも余っているなら(どんな場合？？？) popular yados から選ぶ
    cnt = 0
    while rank < 10 and cnt < len(popular_yados):
        if popular_yados[cnt] in Predict[idx]:
            cnt += 1
            continue
        Predict[idx][rank] = popular_yados[cnt]
        cnt += 1
        rank += 1
    


print(not_enough)
    
df_submit3 = pd.DataFrame(Predict, columns=["predict_0", "predict_1", "predict_2", "predict_3", "predict_4", "predict_5", "predict_6", "predict_7", "predict_8", "predict_9"])
df_submit3.to_csv("out/last_sub.csv", index=False)
# Out:
# 599
